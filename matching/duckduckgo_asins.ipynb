# %% [markdown]
# # `duckduckgo_asins.ipynb`
#
# In this notebook we match incident reports with the ASINs (Amazon Standard Identification Numbers) of the products they concern.
#
# We first use the `find_amazon_link_in_report` function to extract ASINs from Amazon links (including "a.co" short URLs) in the report text.
#
# We then use the `amazon_asin` function, which searches for a product in duckduckgo.com and returns any amazon.com products in the first ten results, along with their asins, and a "matching score" via rapidfuzz.
#
# For example running `amazon_asin("Ace the Data Science Interview: 201 Real Interview Questions by Nick Singh and Kevin Huo")` outputs
# the following:
# ```
# [{'name': 'Ace Data Science Interview Questions',
#   'asin': '0578973839',
#   'score': 100.0},
#  {'name': 'Ace Data Science Interview Interviews',
#   'asin': '1956591133',
#   'score': 82.53968253968254},
#  {'name': 'Ace Data Engineering Interview Questions',
#   'asin': 'B0F18SQNYL',
#   'score': 82.35294117647058}]
#   ```
# **The results are in descending order of closeness of match (according to duckduckgo.com). This may not agree with the rapidfuzz ``score``.**
#
# This is then applied to the incidents reports data, and saved to the "asin_search_results" column in asin_search_results.csv.
#
# We save the results to `df_asin.csv`, which consistis of Amazon ASINs annotated with match status and report indices.

# %%
# By default, we will use the saved results from the scrape in the file asin_with_search_results.csv.
# The scraping took about 5 hours on my computer.
# Setting USE_SAVED_SCRAPE_RESULTS to False will carry out the scrape again, which is necessary if we are using new incident data.
USE_SAVED_SCRAPE_RESULTS=True

# If TESTING is True, the code will only run on a random sample of at most MAX_INCIDENTS rows of the incidient report data.
# If TESTING is False, the code will run on the whole dataset.
TESTING=False
MAX_INCIDENTS=10

# %%
import pandas as pd

# %%
#Import incident report data

report_files=['../Data/Current Version of Toys Incidence+Recall/Toysandchildren_ArtsandCrafts.csv',
              '../Data/Current Version of Toys Incidence+Recall/Toysandchildren_Riding_Toys.csv',
              '../Data/Current Version of Toys Incidence+Recall/Toysandchildren_Toys.csv']
df_arts=pd.read_csv(report_files[0],header=2)
df_riding=pd.read_csv(report_files[1],header=1)
df_toy=pd.read_csv(report_files[2],header=1)
reports=pd.concat([df_arts,df_riding,df_toy   ],ignore_index=True)


to_rename=dict()
for column in reports.columns:
    to_rename[column]=column.replace(' / ','/').replace(' ','_').lower()
reports=reports.rename(columns=to_rename)

del df_riding, df_arts, df_toy, to_rename, report_files,column

# %%
# This contains a few "a.co" short URLs whch I entered the ASINs for manually.
link_lookup={'a.co/d/2299M1u': 'B0BWYHLHHZ',
                'a.co/d/63Rrqnu': 'B08BJYVMHS',
                'a.co/d/6QDqgip': 'B086WNVDTG',
                'a.co/d/7gfkDxl': 'B09Z68Q2K7',
                'a.co/d/7r4Z3S5': 'B095WQHW8L',
                'a.co/d/8jsyfzE': 'B09YHVY42K',
                'a.co/d/aCLKMub': 'B0CDLDCW38',
                'a.co/d/ckJk1jl': 'B0BQQP5WK5',
                'a.co/d/dai68Xv': 'B07Y1V52BT',
                'a.co/d/eOVs4JR': 'B0CHJTD1FS',
                'a.co/d/eV1EXP7': 'B0BWS22GVD',
                'a.co/d/glkRka6': 'B07BQFS9W8',
                'a.co/d/iPLpSs3': 'B0CH8DCDCC',
                'a.co/d/iqx6cmg': 'B0BBDX4W8T'}

# %%
def find_amazon_link_in_report(x):
    for item in x:
        idx=str(item).find('a.co/d/')
        if idx!=-1:
            return link_lookup[str(item)[idx:idx+14]]
        idx=str(item).find('/dp/')
        if idx!=-1:
                return str(item)[idx+4:idx+14]
    return None

# %%
reports['asin_in_report']=reports.apply(find_amazon_link_in_report,axis=1)

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
from scrape_duckduckgo import amazon_asin

# %%
# Limit the number of records if TESTING=true
if TESTING and len(reports)>MAX_INCIDENTS:
    reports=reports.sample(MAX_INCIDENTS,random_state=1066)

# %%
# We define the query column, which is used to search for a product.
# It concatenates the brand, model_name_or_number, and product_description.

reports['query']=reports.brand.fillna('').astype(str)+' '+\
                 reports.model_name_or_number.fillna('').astype(str) + ' ' +\
                 reports.product_description.fillna('').astype(str)

# %%
if USE_SAVED_SCRAPE_RESULTS:
    reports=pd.read_csv("asin_with_search_results.csv",index_col=0)
    from ast import literal_eval
    reports.fillna({'search_result':"[]"},inplace=True)
    reports.search_result=reports.search_result.apply(lambda x : literal_eval(x))
else:
    reports['search_result']=reports['query'].progress_apply(amazon_asin)
    reports=reports.drop(columns=['query'])

# %% [markdown]
# We now see some of the results. It important to note that the product names in the results do not necessarily summarise what the product is.
# For example, consider the product with description ``FLARP- Noise Putty (Pink)Slime product``. One of the returned results is ``Original Glitter Assorted JA RU Scented``, but on visiting the [product's amazon.com page](https://www.amazon.com/Original-Glitter-Assorted-JA-RU-Scented/dp/B098TYWVR1?th=1), we see that the full product name is ``JA-RU Flip & Flarp Noise Putty for Kids Double Pack Original & Glitter (1 Pack Assorted),Farrt Gas Noise Maker Slime Cloud & Scented Putty Fidget Stress Toy for Boys, Girls & Adults. 047-1A ``, which better matches the product description.

# %%
for i,item in reports.iloc[:30].iterrows():
    print("Brand:", item.brand)
    print("Model No:", item.model_name_or_number)
    print("Description:", item.product_description)

    print("Search Results:")
    for result in item.search_result:
        print(result)
    print("\n \n")
# Out:
# Brand: POLKA DROP SLIME
# Model No: nan
# Description: Slime globe with colored spheres which resemble [REDACTED] cereal or [REDACTED]
# Search Results:
# {'name': 'Polka Dot Slime 12 Pack', 'asin': 'B0CJ9XS1NJ', 'score': 35.71428571428571}
# {'name': 'YOPINSAND Galaxy Making Add ins Glitters', 'asin': 'B0D5LX83X3', 'score': 20.799999999999997}
# {'name': 'SLIMYGLOOP MixEms Horizon Sparkly Glitter', 'asin': 'B07N84BJ63', 'score': 20.634920634920633}
# {'name': 'GirlZone Cosmic Premade Glitter Christmas', 'asin': 'B0B2Q8MR4Q', 'score': 28.57142857142857}
#
#
#
# Brand: Nickledodeon Slime
# Model No: Lot #281117
# Description: Slime kit from Nickelodeon by Cra-Z-Art
# Search Results:
# {'name': 'Cra Z Art Nickelodeon Stress Less Slime', 'asin': 'B07VB9PHLH', 'score': 60.714285714285715}
# {'name': 'Cra Z Art Nickelodeon Pre Made Slime Super', 'asin': 'B089MWDPVB', 'score': 57.6271186440678}
#
#
#
# Brand: Lalaloopsy Color Me ( Squiggles N. Shapes )
# Model No: 531463/531470
# Description: Lalaloopsy Color Me Doll ( Squiggles N. Shapes) of MGA Entertainment
# Search Results:
# {'name': 'LalaloopsyTM Color MeTM Doll Removable', 'asin': 'B09P9KK23V', 'score': 46.51162790697674}
# {'name': 'LalaloopsyTM Color MeTM Doll Removable', 'asin': 'B09PB3XQGH', 'score': 46.51162790697674}
#
#
#
# Brand: Play Doh
# Model No: nan
# Description: Play Doh by Hasbro
# Search Results:
# {'name': 'Hasbro Play Doh 4 Pack Colors Ounce', 'asin': 'B00NI36G0O', 'score': 90.9090909090909}
# {'name': 'Play Doh Fun Factory Deluxe Set', 'asin': 'B01BYBUY0Y', 'score': 61.53846153846154}
# {'name': 'Hasbro Play Doh Pack Colors Yellow', 'asin': 'B01GVGD6C0', 'score': 90.9090909090909}
# {'name': 'Play Doh colors Orange Yellow Hasbro', 'asin': 'B01FF1073I', 'score': 90.9090909090909}
# {'name': 'Play Doh Hasbro E4867ES0 Turquoise Orange', 'asin': 'B07KRL84G5', 'score': 90.9090909090909}
# {'name': 'Play Doh Hasbro E4869ES0 Imaginative Creative', 'asin': 'B07KRLJFVX', 'score': 90.9090909090909}
#
#
#
# Brand: Nickelodeon
# Model No: nan
# Description: Cra-z-art Nickelodeon slime party pack
# Search Results:
# {'name': 'Nickelodeon CRA Z Slime Galactic Glitter Medium', 'asin': 'B072QGZNNC', 'score': 56.470588235294116}
# {'name': 'Nickelodeon CRA Z Slime Crunchy Medium Fashion', 'asin': 'B07D9Z3X67', 'score': 52.38095238095238}
# {'name': 'Cra Z Art Nickelodeon Stress Less Slime', 'asin': 'B07VB9PHLH', 'score': 57.142857142857146}
# {'name': 'CRA Z Art Nickelodeon Pre Made Slime Variety', 'asin': 'B09JKXVGVS', 'score': 56.09756097560975}
# {'name': 'Cra Z Art Nickelodeon Slime Food Asst', 'asin': 'B07JYTRZ3L', 'score': 58.666666666666664}
#
#
#
# Brand: Moon Dough
# Model No: Pan Pizza
# Description: set of moon dough, plastic molds, and a purple machine that you load moon dough in the top and crank a lever on the back to mush the dough through a mold. the new shape comes out the bottom of the machine.
# Search Results:
# {'name': 'Crescent Silicone Moonlight Kitchen Bakeware', 'asin': 'B07WSBGQWR', 'score': 22.64150943396227}
# {'name': 'Silicone Crescent Moonlight Kitchen Bakeware', 'asin': 'B08165P6BP', 'score': 22.64150943396227}
# {'name': 'EchoDone Crescent Silicone Moonlight Bakeware', 'asin': 'B086X56GCS', 'score': 23.47417840375587}
# {'name': 'Silicone Baking Cheese Bakeware Pastry', 'asin': 'B08184XRTB', 'score': 20.388349514563103}
# {'name': 'Silikomart Dome shaped Technology Detailing Dishwasher', 'asin': 'B0753HF1Y1', 'score': 26.126126126126124}
# {'name': 'CheeseandU Silicone Crescent Moonlight Mubarak', 'asin': 'B08X6H4HNY', 'score': 21.495327102803742}
# {'name': 'Plastic Oriental Maamoul Eastern Chocolate', 'asin': 'B071D7DTRM', 'score': 24.76190476190476}
#
#
#
# Brand: amaco
# Model No: nan
# Description: modeling clay air dry red
# Search Results:
# {'name': 'American Art Clay 90058J Permoplast', 'asin': 'B0006O03GG', 'score': 36.36363636363637}
# {'name': 'AMACO Mexican Self Hardening Clay 5 Pound', 'asin': 'B0009RLJZE', 'score': 41.666666666666664}
# {'name': 'Modeling Moulding Primary Colors Adults', 'asin': 'B08TZSS53G', 'score': 40.0}
# {'name': 'AMACO AMA48653D Mexican Pottery Self Hardening', 'asin': 'B000CD2L1G', 'score': 31.168831168831176}
# {'name': 'Colors Modeling Molding Sculpting Non Sticky', 'asin': 'B0CNTRYHKK', 'score': 34.66666666666667}
#
#
#
# Brand: Crayola
# Model No: Crayola Mini Twistable Crayon
# Description: Crayola Mini Twistable Crayon
# Search Results:
# {'name': 'Crayola Mini Twistable Crayons Total', 'asin': 'B005NF3RR0', 'score': 89.23076923076923}
# {'name': 'Crayola Twistables Crayons Exclusive Stocking', 'asin': 'B07D4T2XKB', 'score': 72.97297297297297}
# {'name': 'Crayola Mini Twistable Crayons Colors', 'asin': 'B000GLZMGK', 'score': 87.87878787878788}
# {'name': 'Crayola Effects Twistables Crayons 24 Count', 'asin': 'B0033VHDK8', 'score': 69.44444444444444}
# {'name': 'Crayola Twistables Convenient Self Sharpening Twist Up', 'asin': 'B00CI6J3HK', 'score': 60.24096385542169}
# {'name': 'Crayola Twistables Classrooms Preschools Self Sharpening', 'asin': 'B00062J99K', 'score': 56.470588235294116}
# {'name': 'Crayola Mini Twistables Crayons Pack', 'asin': 'B004Y82HDM', 'score': 89.23076923076923}
# {'name': 'Crayola Mini Twistable Crayons 52 9724', 'asin': 'B077ZNKJH4', 'score': 86.56716417910448}
# {'name': 'Crayola Twistables Mini Crayons Pack', 'asin': 'B00JKO4BL6', 'score': 89.23076923076923}
# {'name': 'Crayola Twistables Mini Crayons Pack', 'asin': 'B00QFXD8BE', 'score': 89.23076923076923}
#
#
#
# Brand: Crayola
# Model No: nan
# Description: Crayon
# Search Results:
# {'name': 'Crayola 52 3024 Crayons 24 Colors', 'asin': 'B0765ML9Y1', 'score': 66.66666666666666}
# {'name': 'crayola crayons classpack assorted colors', 'asin': 'b00y4qbjaq', 'score': 43.63636363636363}
# {'name': 'Crayola Glitter Crayons Supplies 24Count', 'asin': 'B07VXRZTB2', 'score': 66.66666666666666}
# {'name': 'Crayola Crayons 8 Count Standard Size', 'asin': 'B002IXI4MI', 'score': 66.66666666666666}
# {'name': 'Crayola 52 0064 Crayons 64 ea', 'asin': 'B00004YO15', 'score': 66.66666666666666}
# {'name': 'Crayola large crayons Crayons 52 0336', 'asin': 'B004LBXW7W', 'score': 66.66666666666666}
#
#
#
# Brand: Crayola
# Model No: nan
# Description: Crayola Crayons
# Search Results:
# {'name': 'Crayola 52 3024 Crayons 24 Colors', 'asin': 'B0765ML9Y1', 'score': 100.0}
# {'name': 'crayola crayons classpack assorted colors', 'asin': 'b00y4qbjaq', 'score': 46.42857142857143}
# {'name': 'Crayola Crayons Non Toxic Coloring Supplies', 'asin': 'B00MOYTKRE', 'score': 100.0}
# {'name': 'Crayola crayola Crayons 24 Pack', 'asin': 'B0096XWNNY', 'score': 100.0}
# {'name': 'Crayola Crayons Count Bundle Pack', 'asin': 'B0819WBS4J', 'score': 100.0}
# {'name': 'Crayola Crayons Assorted Toddler 16Count', 'asin': 'B07L6VQDSC', 'score': 100.0}
# {'name': 'Crayola Sharpener Non Toxic Classrooms Preschools', 'asin': 'B06Y5XMT7D', 'score': 63.63636363636363}
# {'name': 'Crayola 52 0064 Crayons 64 ea', 'asin': 'B00004YO15', 'score': 100.0}
#
#
#
# Brand: Block Crayon 6020
# Model No: nan
# Description: Block Crayon http://blockcrayon.com/products.phpPurchased at Costco the Farm set it has bllock crayons that stack and includes animal shaped crayons. It came with a coloring book and about 14 animals and 30 or so blocks. All different colors. Block Crayon Club Pack 6020 and UPC Code:  62884506020
# Search Results:
# {'name': 'Stockmar Beeswax Crayons Assorted Waldorf', 'asin': 'B0010XCT4G', 'score': 22.026431718061673}
# {'name': 'Stockmar Beeswax Block Crayons Set', 'asin': 'B000M02MNG', 'score': 25.641025641025635}
# {'name': 'Stockmar Beeswax Block Crayons Colors', 'asin': 'B07K57M1KX', 'score': 25.11210762331838}
# {'name': 'Stockmar Beeswax Block Crayons Standard', 'asin': 'B0007QJ7ZG', 'score': 24.888888888888886}
# {'name': 'Crayons Organic Handmade Paraffin Petroleum', 'asin': 'B018SWCXKQ', 'score': 25.327510917030565}
# {'name': 'Honeysticks Toddlers Food Grade Coloring Preschool', 'asin': 'B0CNS9YRQD', 'score': 25.423728813559322}
#
#
#
# Brand: Block Crayon
# Model No: nan
# Description: http://blockcrayon.com/index.php  Crayons formed into the shapes of blocks and small people/animals. Animals in particular are rounded and about the size of a half-dollar coin. Could be made smaller by wearing down crayon material that they are made of.
# Search Results:
# {'name': 'Crayons Organic Handmade Paraffin Petroleum', 'asin': 'B018SWCXKQ', 'score': 28.0}
# {'name': 'Stockmar Beeswax Crayons Assorted Waldorf', 'asin': 'B0010XCT4G', 'score': 29.16666666666667}
# {'name': 'Stockmar Beeswax Block Crayons Standard', 'asin': 'B0007QJ7ZG', 'score': 50.0}
# {'name': 'Stockmar Beeswax Block Crayons Colors', 'asin': 'B07K57M1KX', 'score': 52.0}
# {'name': 'Stockmar Beeswax Block Crayons Set', 'asin': 'B000M02MNG', 'score': 55.319148936170215}
# {'name': 'STOCKMAR Beeswax Crayons Blocks Carton', 'asin': 'B003H6I5CO', 'score': 31.111111111111114}
# {'name': 'Stockmar Combined Assortment Crayons Blocks', 'asin': 'B0013MZA7C', 'score': 29.6943231441048}
# {'name': 'Honeysticks Toddlers Food Grade Coloring Preschool', 'asin': 'B0CNS9YRQD', 'score': 26.271186440677965}
# {'name': 'FAMILIDOO BeesWax Crayon Creativity Toddlers', 'asin': 'B0BKSYDGZV', 'score': 24.0}
#
#
#
# Brand: Creative Kids
# Model No: nan
# Description: Create Your Own Magic Bouncy Balls:  Create fun bouncing balls using vibrant colors and fun shaped molds in this Magic Bouncing Balls kit. Customize your own designs inside the mold, place in water and in just minutes, you are ready for high bouncing fun! Kit includes:    20 Bags Multi Colored Crystal Powder    Five Molds    Instructions http://www.hobbylobby.com/Crafts-%26-Hobbies/Kids-Crafts-%26-Activities/Activity-%26-Craft-Kits/Magic-Bouncing-Balls/p/26907Ages 6+
# Search Results:
# {'name': 'Creative Kids Magic Bouncy Balls', 'asin': 'B078KKQ343', 'score': 100.0}
# {'name': 'creative kids magic bouncy factory', 'asin': 'b07v1jffbz', 'score': 25.116279069767444}
# {'name': 'Creative Kids Make Bouncy Craft', 'asin': 'B08Q226BHX', 'score': 78.43137254901961}
# {'name': 'Make Your Own Bouncy Ball', 'asin': 'B07YGZMQHC', 'score': 75.0}
# {'name': 'Creative Kids Arts Crafts Kit', 'asin': 'B08YGJV94W', 'score': 61.904761904761905}
# {'name': 'Blue Marble Bouncy Ball Science', 'asin': 'B0D33WHMW9', 'score': 32.432432432432435}
#
#
#
# Brand: Castle Molds from wabafun.com  2014WABA Fun, LLC
# Model No: LOT # MS0514CN13121 Castl Molds 192-101
# Description: Castle Molds from wabafun.com Purchased from Constructive Playthings catalog8 tools to make a fun castle! Lot#MS0514CN13121Castle Molds 192-101Manufactured for and distributed by WABA Fun LLC under license from Delta of Sweden AB, WABA Fun LLC, 13654 Xavier Ln. #202 Broomfield, CO  90023
# Search Results:
# {'name': 'Waba Fun Miniature Castle Molds', 'asin': 'B019P7RY8O', 'score': 55.81395348837209}
# {'name': 'Castle Bucket Shovel Sandbox Toddlers', 'asin': 'B0CYZF3194', 'score': 27.906976744186053}
# {'name': 'CoolSand Building Sand Molds Tools', 'asin': 'B06XSPBQ3Q', 'score': 26.04166666666667}
# {'name': 'Liberty Imports Piece Castle Building', 'asin': 'B06Y3MNS7Q', 'score': 27.906976744186053}
# {'name': 'Top Race Castle Buckets Beach', 'asin': 'B01GIB3O3O', 'score': 34.28571428571429}
# {'name': 'Waba Fun BLP90102 Castle Molds', 'asin': 'B004Y7WSG4', 'score': 57.142857142857146}
# {'name': 'Spring Summer Sandcastle Building Multicolor', 'asin': 'B0BB1RC8XG', 'score': 24.752475247524757}
#
#
#
# Brand: Crayola
# Model No: 42002AGO
# Description: Crayola Bath Gel Doodlers CrayonsThe model number is 42002AGO
# Search Results:
# {'name': 'Crayola Bath Doodles Jumbo Small', 'asin': 'B0CSS6LRJF', 'score': 54.54545454545455}
# {'name': 'Crayola Bath Toy Super Set', 'asin': 'B0DPNLQZ3H', 'score': 63.1578947368421}
# {'name': 'Crayola Bath Shower Toys Bundle', 'asin': 'B0B8113Y1J', 'score': 55.81395348837209}
# {'name': 'Crayola Super Bundle Tubes Bubbly', 'asin': 'B0BF8L99RW', 'score': 42.5531914893617}
#
#
#
# Brand: Play Doh
# Model No: nan
# Description: Play Doh
# Search Results:
# {'name': 'Play Doh B9017AF0 Modeling Compound Schoolpack', 'asin': 'B01FAPXB0K', 'score': 100.0}
# {'name': 'Play Doh Multipack 47 Piece Non Toxic Exclusive', 'asin': 'B085WNJ7JW', 'score': 100.0}
# {'name': 'Play Doh B1169 Starter Set', 'asin': 'B00TPMDNSU', 'score': 100.0}
# {'name': 'Play Doh Modeling Compound Non Toxic Exclusive', 'asin': 'B00JM5GW10', 'score': 100.0}
#
#
#
# Brand: Playskool
# Model No: nan
# Description: Green Playskool crayon, approximately 4 inches long
# Search Results:
# {'name': 'Playskool Premium Multicolour Washable Crayons', 'asin': 'B0DBVRG65Q', 'score': 43.29896907216495}
# {'name': 'Playskool Non Toxic Kindergarten Preschool Multi Color', 'asin': 'B09RSG3224', 'score': 47.61904761904762}
# {'name': 'Playskool 10 Count Crayons Classrooms Classic', 'asin': 'B07TLFRR1C', 'score': 50.0}
# {'name': 'Playskool 64 Count Crayons Built Sharpener', 'asin': 'B00413Q53I', 'score': 53.763440860215056}
# {'name': 'Playskool 10 Count Washable Markers Total', 'asin': 'B01CF36SEQ', 'score': 47.82608695652174}
# {'name': 'Playskool Crayon Set Classic', 'asin': 'B01M6VF5S5', 'score': 50.63291139240506}
# {'name': 'Playskool Jumbo Crayons Safety Scissors', 'asin': 'B00SCAYU3S', 'score': 48.888888888888886}
# {'name': 'Playskool Bright Colors Crayon Box', 'asin': 'B00D5D9DRU', 'score': 49.411764705882355}
#
#
#
# Brand: nan
# Model No: BSJIXI0618
# Description: My son received a goody bag from school with products from the Oriental Trading Company. I opened the container of slime and he took it out. Soon after, I noticed a dark line in the white slime. It turned out to be a sharp, pointed piece of plastic.
# Search Results:
# {'name': 'Fun Express Bright Color Paper', 'asin': 'B00WVPDOXC', 'score': 18.00947867298578}
# {'name': 'Goodie Bags 24 Stickers Birthday Supplies', 'asin': 'B08DV9XVGT', 'score': 23.42342342342343}
# {'name': 'Fun Express Rejoice Plastic Supplies', 'asin': 'B07PNRBH3Z', 'score': 20.27649769585254}
#
#
#
# Brand: FLARP
# Model No: FLARP- Pink
# Description: FLARP- Noise Putty (Pink)Slime product
# Search Results:
# {'name': 'Original Glitter Assorted JA RU Scented', 'asin': 'B098TYWVR1', 'score': 29.545454545454547}
# {'name': 'JA RU Original Glitter Assorted Scented', 'asin': 'B098V1MG6X', 'score': 29.545454545454547}
# {'name': 'Scented Assorted Squishy Sensory 10041 1p', 'asin': 'B07GG2FGLH', 'score': 24.444444444444443}
# {'name': 'JA RU Bouncy Squish Sounds 10041 4p', 'asin': 'B07DX9BJNP', 'score': 23.80952380952381}
# {'name': 'JA RU Flarp Squish Sounds 10041 3', 'asin': 'B07GG2GFZG', 'score': 24.390243902439025}
# {'name': 'JA RU Inc B00DVM3V78 Ja Ru Flarp', 'asin': 'B00DVM3V78', 'score': 19.75308641975309}
# {'name': 'HANDGUP Adults Pack Original Luminous Glitter', 'asin': 'B0BPSXQFBR', 'score': 34.04255319148936}
# {'name': 'JA RU Flarp Noise Bouncy 335 1slp', 'asin': 'B07P7RFD1G', 'score': 31.707317073170728}
# {'name': 'Original Glitter Assorted JA RU Scented', 'asin': 'B098V1VBX3', 'score': 29.545454545454547}
#
#
#
# Brand: Crayola twistables
# Model No: nan
# Description: Crayola twistables
# Search Results:
# {'name': 'Crayola Effects Twistables Crayons 24 Count', 'asin': 'B0033VHDK8', 'score': 59.01639344262295}
# {'name': 'Crayola Twistables Classrooms Preschools Self Sharpening', 'asin': 'B00062J99K', 'score': 56.0}
# {'name': 'Crayola Twistables Crayons Exclusive Stocking', 'asin': 'B07D4T2XKB', 'score': 57.142857142857146}
# {'name': 'Crayola 27139115 Twistables 8 ct', 'asin': 'B000YJRTOM', 'score': 68.0}
# {'name': 'Crayola Twistables Colored Exclusive Stocking', 'asin': 'B07D4RN9NH', 'score': 57.142857142857146}
# {'name': 'CrayolaTwistables Crayons Pack 24 Multicolour', 'asin': 'B00O10TDZ8', 'score': 50.79365079365079}
# {'name': 'Crayola Crayons Washable', 'asin': 'B00GRT0DSW', 'score': 61.904761904761905}
# {'name': 'Crayola 52 7408 Twistables Crayons', 'asin': 'B00178Q28S', 'score': 65.38461538461539}
#
#
#
# Brand: Flarp
# Model No: 335
# Description: 16 oz Flarp! noise putty
# Search Results:
# {'name': 'JA RU Flarp Noise Bouncy 335 1slp', 'asin': 'B07LC38GW3', 'score': 59.701492537313435}
# {'name': 'JA RU Inc B00DVM3V78 Ja Ru Flarp', 'asin': 'B00DVM3V78', 'score': 36.36363636363637}
# {'name': 'Scented Assorted Squishy Sensory 10041 1p', 'asin': 'B07GG2FGLH', 'score': 34.66666666666667}
# {'name': 'Original Glitter Assorted JA RU Scented', 'asin': 'B098TYWVR1', 'score': 24.657534246575338}
# {'name': 'JA RU SG_B00DC7FXDC_US FLARP NOISE PUTTY', 'asin': 'B00DC7FXDC', 'score': 13.513513513513516}
# {'name': 'JA RU Flarp Noise Putty Variety', 'asin': 'B0DQLZ78BQ', 'score': 49.23076923076923}
# {'name': 'JA RU Scented Squishy Sensory Supplies', 'asin': 'B0844QDVHC', 'score': 25.0}
# {'name': 'JA RU Flarp Noise Bouncy 335 1slp', 'asin': 'B07P7RFD1G', 'score': 59.701492537313435}
# {'name': 'Scented Assorted Squishy Sensory 10041 1A', 'asin': 'B07FN52KMG', 'score': 32.0}
#
#
#
# Brand: Crayola
# Model No: 57-6001
# Description: Crayola Model Magic Putty/ ClayModel 57-6001This is a neon green hand putty that you can mold into an object. when you leave the ham putty out it forms into a hard object that you can put for display.
# Search Results:
# {'name': 'Crayola Lightweight Modeling Material Decorate', 'asin': 'B00FY2OWK8', 'score': 26.41509433962264}
# {'name': 'Crayola Model Magic Orange 4 Ounce', 'asin': 'B00FY2OZLY', 'score': 71.69811320754717}
# {'name': 'Crayola 57 6001 096 Model 4oz Neon Yellow', 'asin': 'B00P8DZTDW', 'score': 48.148148148148145}
# {'name': 'Crayola Classpack Lightweight Modeling Material', 'asin': 'B00027C7KC', 'score': 25.961538461538467}
# {'name': 'Crayola Model Magic 4 Ounce Pouch', 'asin': 'B00006IBOZ', 'score': 73.07692307692308}
# {'name': 'Crayola Model Single Secondary Colors', 'asin': 'B000OL3LF6', 'score': 52.0}
# {'name': 'Crayola Model Magic Deluxe Variety', 'asin': 'B00004UE4A', 'score': 71.69811320754717}
# {'name': 'Crayola 57 4444 Model Height Length', 'asin': 'B00178JVXQ', 'score': 54.166666666666664}
# {'name': 'Crayola 4 Ounce Purple Modeling Alternative', 'asin': 'B00BSB4ES4', 'score': 29.411764705882348}
#
#
#
# Brand: Anker Art
# Model No: 450241/OB
# Description: Anker Art Scenty's Slime Diner Lunch Special with 15 Food Scented Pre-made Slime Tubs. Model 450241/OBColorful box, approximately29cm x 32cm x 5 cm in dimension. Has food scented slime 1oz tubs. Only has a choking hazard warning.Labled for ages 6 and up. I believe actual food extracts are used for scent.Brand: Anker ArtDistributor: Anker Play Products. Miami Beach Florida, 33139Manufacturer Location: Ningbo, China
# Search Results:
# {'name': 'Anker Art Station Different Slimes', 'asin': 'B07KVPMQFW', 'score': 41.86046511627907}
# {'name': 'Anker Art Gold Rush Slime', 'asin': 'B085LQZNY3', 'score': 75.0}
#
#
#
# Brand: Zuru - Rainbocorns Sweet-Shake Surprise
# Model No: nan
# Description: Zuru - Rainbocorns Sweet-Shake Surprise.  This items comes with a powder you mix with water to turn into a slime, my complaint is specifically with the slime powder.
# Search Results:
# {'name': 'ZURU Rainbocorns 9212H Surprise Monkeycorn', 'asin': 'B08779X8LQ', 'score': 64.51612903225806}
# {'name': 'Rainbocorns Plush Sweet Shake Surprise', 'asin': 'B083TPTLGG', 'score': 68.9655172413793}
# {'name': 'Rainbocorns BUNNYCORN Surprise 1 2PK ZURU', 'asin': 'B09NR1F4GL', 'score': 65.57377049180329}
# {'name': 'Zuru 9297 Rainbocorns Monstercorn Surprise', 'asin': 'B0D9QKKQNT', 'score': 74.6268656716418}
# {'name': 'ZURU Rainbocorns 9212A Surprise Bunnycorn', 'asin': 'B0877FNLZ2', 'score': 65.57377049180329}
# {'name': 'ZURU 92105 Zuru Rainbocorns Adopt a Corn', 'asin': 'B0DBJ4JV2S', 'score': 62.06896551724138}
# {'name': 'Zuru Surprise Rainbocorns Bunnycorn Plush', 'asin': 'B0CP86NDH5', 'score': 75.75757575757575}
# {'name': ' /es/Rainbocorns 9212A Sweet Surprise Bunnycorn', 'asin': 'B0877FNLZ2', 'score': 33.83084577114428}
#
#
#
# Brand: Chuckle & Roar
# Model No: nan
# Description: Chuckle & Roar 2-in-1 Seek & Write Sensory Bin
# Search Results:
# {'name': 'Chuckle Roar Montessori Preschool Activities', 'asin': 'B0D3624MWJ', 'score': 54.54545454545455}
# {'name': 'Chuckle Roar Montessori Preschool Activities', 'asin': 'B0C2VYF2JF', 'score': 54.54545454545455}
# {'name': 'Chuckle Roar Sensory Scavanger Toddlers', 'asin': 'B0CV64CZCQ', 'score': 67.79661016949152}
# {'name': 'Chuckle Roar Activities Preschool Montessori', 'asin': 'B0CNBQFN9R', 'score': 54.54545454545455}
# {'name': 'Chuckle Roar Sensory Engagement Preschoolers', 'asin': 'B0DVZKZP46', 'score': 62.5}
# {'name': 'Chuckle Roar Flashlight Seek Find', 'asin': 'B0BZT6WC2C', 'score': 68.0}
# {'name': 'Chuckle Roar Sensory 10pk Fidget', 'asin': 'B0C2VVHNSP', 'score': 76.92307692307692}
#
#
#
# Brand: Kawaii Slime Company
# Model No: Watermelon Sugar Fishbowl Slime
# Description: All Kawaii Slime Products were missing the essential information.  It is a slime with small parts and whipped cream looking topping in what appears to be a food container style packaging.  Sprinkles were also packaged in containers typically seen in the baking aisle with no information regarding manufacturer or warnings of any kind.
# Search Results:
# {'name': 'Slimygloop Kawaii 6 Pack Scented Glitter', 'asin': 'B0D94PXBBF', 'score': 26.086956521739125}
# {'name': 'Watermelon Add ins Sensory Birthday Hallowmas', 'asin': 'B0D7H1XJWQ', 'score': 36.36363636363637}
# {'name': 'Butter Unicorn Suppulies Scented Stretchy', 'asin': 'B09DYZ5FY5', 'score': 20.814479638009047}
#
#
#
# Brand: Elmer's
# Model No: Item code 2095928
# Description: Elmer's Magical Liquid Slime Activator (Elmer's Magical Liquid 2.0), 1 qt opaque bottle with orange label, item code 2095928
# Search Results:
# {'name': 'Elmers Magical Liquid Activator Solution', 'asin': 'B07KYHSN8N', 'score': 75.0}
# {'name': 'Elmers Magical Activator Solution Batches', 'asin': 'B07C368YY2', 'score': 58.62068965517241}
# {'name': 'Elmers Fluffy Activator Magical Solution', 'asin': 'B0C53BCDZG', 'score': 59.64912280701754}
# {'name': 'Elmers Crunchy Activator Magical Liquid', 'asin': 'B089N5J8QH', 'score': 76.19047619047619}
# {'name': 'Elmers Liquid Washable Ounces Making', 'asin': 'B078WFMB6R', 'score': 33.33333333333333}
# {'name': 'Elmers Magical Liquid Activator Solution', 'asin': 'B07QHP9NCQ', 'score': 75.0}
# {'name': 'Elmers Magical Liquid Activator Solution', 'asin': 'B076JVC67K', 'score': 75.0}
# {'name': 'Elmers Activator Magical Scented Tropical', 'asin': 'B083CRJ44W', 'score': 58.62068965517241}
# {'name': 'Elmers Activator Magical Scented Limeade', 'asin': 'B083CR65DR', 'score': 59.64912280701754}
# {'name': 'Elmers Metallic Activator Magical Liquid', 'asin': 'B07VZKDNLG', 'score': 75.0}
#
#
#
# Brand: Elmer's
# Model No: Magic liquid
# Description: Elmer's magic liquid
# Search Results:
# {'name': 'Elmers Magical Liquid Activator Solution', 'asin': 'B07KYHSN8N', 'score': 51.515151515151516}
# {'name': 'Elmers Magical Liquid Activator Solution', 'asin': 'B07QHP9NCQ', 'score': 51.515151515151516}
# {'name': 'Elmers Magical Liquid Activator Solution', 'asin': 'B076JVC67K', 'score': 51.515151515151516}
# {'name': 'Elmers Activator Magical Liquid Scented', 'asin': 'B083CS8RNV', 'score': 52.30769230769231}
# {'name': 'Elmers Electrifying Glow Liquid 2062245', 'asin': 'B07GX2559X', 'score': 40.0}
# {'name': 'Elmers Magical Activator Solution Batches', 'asin': 'B07C368YY2', 'score': 47.76119402985075}
# {'name': 'Elmers Fluffy Activator Magical Solution', 'asin': 'B0C53BCDZG', 'score': 48.484848484848484}
# {'name': 'Elmers Magical Liquid Solution Bottle', 'asin': 'B086WSYSD4', 'score': 53.96825396825397}
# {'name': 'Elmers X Acto E2074028 Crunchy Magical', 'asin': 'B07YSV1G6G', 'score': 43.75}
# {'name': 'Elmers Crunchy Activator Magical Liquid', 'asin': 'B07VV72KGP', 'score': 52.30769230769231}
#
#
#
# Brand: Angel of Mine
# Model No: mini silicone popsicle mold
# Description: Mini silicone popsicle molds marketed under the brand Angel of Mine that are being sold for use by babies.  The parts include a one piece silicone mold with four wells to fill with juice, fruit, baby food (specifically mentioned on packaging), before freezing. Included are four plastic stick like handles (approximately 3 inches long by 3/4 of an inch wide at the widest point, and  thickness that varies from 1/8th of an inch to 5/16th of an inch thick at the thickest point of the stick) and caps for each well. The handles are meant to click securely into the caps and then the assembled cap/stick are to be placed into the food or liquid to be placed in the freezer and be frozen to create a small popsicle. Unfortunately, THE STICK PORTION DOES NOT CLICK FIRMLY INTO THE CAP and can come detached fairly easily, posing a real choking hazard for a small baby or toddler.
# Search Results:
# {'name': 'Silicone Popsicle 7 cavity Container Non Stick', 'asin': 'B07SGPW5WS', 'score': 31.155778894472363}
# {'name': 'Popsicle Mini Silicone Colorful Non Stick', 'asin': 'B0F3X815T6', 'score': 32.98969072164948}
# {'name': 'Silicone Popsicle Reusable Cavities Non Stick', 'asin': 'B0C9JHRH1Y', 'score': 29.292929292929287}
# {'name': 'Popsicle Homemade Silicone BPA Free Cleaning', 'asin': 'B07TWKJ6TN', 'score': 33.502538071065985}
# {'name': 'Popsicles Molds Mini Popsicle Pineapple', 'asin': 'B0C5X7YVX2', 'score': 32.29166666666667}
# {'name': 'Popsicle Mould%EF%BC%8CPopsicle Silicone Reusable Release', 'asin': 'B086M3XY8Z', 'score': 29.52380952380952}
#
#
#
# Brand: Cra-Z-Art Cra-Z-Slimy Sparkle Fairy Slime, Purple
# Model No: nan
# Description: Cra-Z-Art Cra-Z-Slimy Sparkle Fairy Slime, Purpleit's a slime with sparkleshttps://www.walmart.com/ip/Cra-Z-Art-Cra-Z-Slimy-Sparkle-Fairy-Slime-Purple-Ages-6-and-up/2317953960?wmlspartner=wlpa&selectedSellerId=0&wl13=2281&gclsrc=aw.ds&adid=222222222772317953960_117755028669_12420145346&wl0=&wl1=g&wl2=c&wl3=501107745824&wl4=pla-394283752452&wl5=9005925&wl6=&wl7=&wl8=&wl9=pla&wl10=8175035&wl11=local&wl12=2317953960&veh=sem_LIA&gclsrc=aw.ds&gad_source=1&gclid=EAIaIQobChMIjIKflbj_iwMVL0ZHAR38FjizEAQYBSABEgKrjfD_BwE
# Search Results:
# {'name': 'Cra Z Art CRA Z Slimy Premade Single Random', 'asin': 'B0794ZR6XW', 'score': 27.411167512690355}
# {'name': 'CRA Z Slimy Sparkle Cotton Scented Premade', 'asin': 'B0DPR8FS11', 'score': 28.57142857142857}
# {'name': 'Cra Z Art 18815 CRA Z Slimy Premade Included', 'asin': 'B0794QNVDM', 'score': 24.24242424242425}
# {'name': 'CRA Z Art Cra Z Slimy Fluffy Multicolor Premade', 'asin': 'B0CCK47T2M', 'score': 26.86567164179104}
# {'name': 'Cra Z Slimy Slimy Blendz Premade Slime', 'asin': 'B0BFHZ6GPQ', 'score': 24.468085106382972}
# {'name': 'Cra Z Art CRA Z Slimy Washable Clear Multi', 'asin': 'B0794PMT5V', 'score': 28.57142857142857}

# %%
# Load amazon metadata asins
amazon_meta_df=pd.read_pickle("../Data/metadata_raw.pkl")[['asin']]

# %%
# Add "match" and "indices" columns to amazon_meta_df

def build_asin_dict():
    asins=dict()
    for index,report in reports.iterrows():
        if report.notna().asin_in_report:
            asin=report.asin_in_report.lower()
            asins[asin]=asins.get(asin,list())
            asins[asin].append(index)
        if report.notna().search_result:
            for result in report.search_result:
                asin=result['asin'].lower()
                asins[asin]=asins.get(asin,list())
                asins[asin].append(index)

    return asins
asins=build_asin_dict()
amazon_meta_df['indices']=amazon_meta_df.asin.apply(lambda x : asins.get(x.lower(),[]))
amazon_meta_df['match']=amazon_meta_df.indices.apply(lambda x: int(x!=[]))

# %%
amazon_meta_df.to_csv("df_asin.csv",columns=['match','indices'])

# %%
amazon_meta_df=pd.read_pickle("../Data/metadata_raw.pkl")

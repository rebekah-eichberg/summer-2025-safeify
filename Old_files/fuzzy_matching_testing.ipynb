# %%
# Download Amazon 2018 toy & games review and metadata
# %cd ../Data/
# %run download_amazon_data.py
# %cd ../alex_fuzzy_matching/
# Out:
# /home/alex/Documents/erdos/summer-2025-safeify/Data
# File already exists.
# File already exists.
# /home/alex/Documents/erdos/summer-2025-safeify/alex_fuzzy_matching

# %%
import pandas as pd

# %%
# Import first 100,000 entries of amazon metadata into a pandas dataframe.
# Obviously we'd want to do this on the full dataset, but my computer struggled importing the full dataset due to RAM limitations
meta_chunks=pd.read_json("../Data/amazon_meta.json",lines=True,chunksize=100_000)
metadata=next(meta_chunks)

# %%
# Import CPSC IncidentReports
reports=pd.read_csv("../Data/IncidentReports.csv",encoding='cp1252')

# Filter to reports in the Toys and Children category. (There's also a baby category.)
reports=reports.loc[reports['Product Category']=='Toys & Children']

# Filter to reports of items manufactured before October 2018,
# since items manufuctered after this data won't appear in the amazon dataset
reports['Date Manufactured']=pd.to_datetime(reports['Date Manufactured'])
report=reports[reports['Date Manufactured']<='Oct 2018']
# Out:
# /tmp/ipykernel_62849/612986380.py:2: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   reports=pd.read_csv("../Data/IncidentReports.csv",encoding='cp1252')

# %%
# Features we can use for fuzzy matching.

print(metadata.columns)
print(reports.columns)
# Out:
# Index(['category', 'tech1', 'description', 'fit', 'title', 'also_buy', 'tech2',
#        'brand', 'feature', 'rank', 'also_view', 'main_cat', 'similar_item',
#        'date', 'price', 'asin', 'imageURL', 'imageURLHighRes', 'details'],
#       dtype='object')
# Index(['Report No.', 'Report Date',
#        'Sent to Manufacturer / Importer / Private Labeler', 'Publication Date',
#        'Category of Submitter', 'Product Description', 'Product Category',
#        'Product Sub Category', 'Product Type', 'Product Code',
#        'Manufacturer / Importer / Private Labeler Name', 'Brand',
#        'Model Name or Number', 'Serial Number', 'UPC', 'Date Manufactured',
#        'Manufacturer Date Code', 'Retailer', 'Retailer State', 'Purchase Date',
#        'Purchase Date Is Estimate', 'Incident Description', 'City', 'State',
#        'ZIP', 'Location', '(Primary) Victim Severity',
#        '(Primary) Victim's Sex', 'My Relation To The (Primary) Victim',
#        '(Primary) Victim's Age (years)', 'Submitter Has Product',
#        'Product Was Damaged Before Incident', 'Damage Description',
#        'Damage Repaired', 'Product Was Modified Before Incident',
#        'Have You Contacted The Manufacturer', 'If Not Do You Plan To',
#        'Answer Explanation', 'Company Comments', 'Associated Report Numbers'],
#       dtype='object')

# %%
import rapidfuzz as rf

# %%
def best_match(query,choices):
    """Function returning best match of "query" in "choices"
    Returns:
        tuple: A tuple consisting of the following elemnts:
            - The best match choice in choices
            - A normalized "edit distance"
            - The index of the best match.
    """
    return rf.process.extractOne(query,choices,scorer=rf.fuzz.ratio)

# %%
reports
# Out:
#                       Report No. Report Date  \
# 5         20250225-EC92A-5152930   2/25/2025
# 18     20250430-BD4AC-2147331626   4/30/2025
# 29     20250426-11C99-2147331693   4/26/2025
# 35     20250425-00047-2147331727   4/25/2025
# 47     20250419-2B92E-2147331854   4/19/2025
# ...                          ...         ...
# 61891  20110312-F8C6F-2147481550   3/12/2011
# 61908  20110312-200A5-2147481542   3/12/2011
# 61939  20110311-C0123-2147481592   3/11/2011
# 61943     20110311-E518D-1170349   3/11/2011
# 61944  20110313-2E80A-2147481520   3/13/2011
#
#       Sent to Manufacturer / Importer / Private Labeler Publication Date  \
# 5                                              5/5/2025        5/19/2025
# 18                                             5/2/2025        5/16/2025
# 29                                             5/1/2025        5/15/2025
# 35                                             5/1/2025        5/15/2025
# 47                                            4/24/2025        5/15/2025
# ...                                                 ...              ...
# 61891                                               NaN         4/6/2011
# 61908                                               NaN         4/2/2011
# 61939                                               NaN         4/1/2011
# 61943                                               NaN         4/1/2011
# 61944                                               NaN         4/1/2011
#
#       Category of Submitter  \
# 5                  Consumer
# 18                 Consumer
# 29                 Consumer
# 35                 Consumer
# 47                 Consumer
# ...                     ...
# 61891              Consumer
# 61908              Consumer
# 61939              Consumer
# 61943              Consumer
# 61944              Consumer
#
#                                      Product Description Product Category  \
# 5                                           sleeping aid  Toys & Children
# 18     100 Pcs Large Stepped Pyramid Wooden Stacking ...  Toys & Children
# 29     Magnetic building tiles by Anbalulu\r\nMagneti...  Toys & Children
# 35     Easter Battery Operated Bubble Wand (way to ce...  Toys & Children
# 47                                     PetsBoro Bunnypal  Toys & Children
# ...                                                  ...              ...
# 61891                               Child's toy stroller  Toys & Children
# 61908  Recalled Graco Stroller (the one with fingerti...  Toys & Children
# 61939               Friendly Faces Royal Princess Rattle  Toys & Children
# 61943  Airzone Pop stick. Bright/ lime green with bla...  Toys & Children
# 61944  Beige colored dog toy which has a bone shaped ...  Toys & Children
#
#         Product Sub Category                                  Product Type  \
# 5                       Toys  Dolls, Plush Toys, and Action Figures (1394)
# 18                      Toys     Blocks, Stacking Toys or Pull Toys (1326)
# 29                      Toys                          Building Sets (1345)
# 35                      Toys         Toys, Not Elsewhere Classified (1381)
# 47                      Toys  Dolls, Plush Toys, and Action Figures (1394)
# ...                      ...                                           ...
# 61891                   Toys  Dolls, Plush Toys, and Action Figures (1394)
# 61908  Strollers & Car Seats                         Baby Strollers (1522)
# 61939                   Toys                           Baby Rattles (1517)
# 61943                   Toys                            Pogo Sticks (1310)
# 61944                   Toys  Dolls, Plush Toys, and Action Figures (1394)
#
#       Product Code  ... Submitter Has Product  \
# 5             1394  ...                   Yes
# 18            1326  ...                    No
# 29            1345  ...                   Yes
# 35            1381  ...                   NaN
# 47            1394  ...                   NaN
# ...            ...  ...                   ...
# 61891         1394  ...                   Yes
# 61908         1522  ...                    No
# 61939         1517  ...                    No
# 61943         1310  ...                   Yes
# 61944         1394  ...                   Yes
#
#       Product Was Damaged Before Incident Damage Description Damage Repaired  \
# 5                                      No                NaN             NaN
# 18                                    Yes                NaN             NaN
# 29                                     No                NaN             NaN
# 35                                    NaN                NaN             NaN
# 47                                    NaN                NaN             NaN
# ...                                   ...                ...             ...
# 61891                                  No                NaN             NaN
# 61908                                  No                NaN             NaN
# 61939                                  No                NaN             NaN
# 61943                                  No                NaN              No
# 61944                                  No                NaN             NaN
#
#       Product Was Modified Before Incident  \
# 5                                       No
# 18                                     NaN
# 29                                     NaN
# 35                                     NaN
# 47                                     NaN
# ...                                    ...
# 61891                                   No
# 61908                                   No
# 61939                                   No
# 61943                                   No
# 61944                                   No
#
#       Have You Contacted The Manufacturer If Not Do You Plan To  \
# 5                                     Yes                   NaN
# 18                                     No                   NaN
# 29                                     No                   NaN
# 35                                    NaN                   NaN
# 47                                    NaN                   NaN
# ...                                   ...                   ...
# 61891                                  No                    No
# 61908                                 Yes                   NaN
# 61939                                 Yes                   NaN
# 61943                                  No                    No
# 61944                                  No                    No
#
#                                       Answer Explanation  \
# 5                                             Sent email
# 18     Blocks chipped when played with. Toy was throw...
# 29                                                   NaN
# 35                                                   NaN
# 47                                                   NaN
# ...                                                  ...
# 61891                                                NaN
# 61908                    Reported the incident to Graco.
# 61939  I contacted them, they requested that I send t...
# 61943                                                NaN
# 61944                                                NaN
#
#                                         Company Comments  \
# 5                                                    NaN
# 18                                                   NaN
# 29                                                   NaN
# 35                                                   NaN
# 47                                                   NaN
# ...                                                  ...
# 61891                                                NaN
# 61908  (3/25/2011) Newell Rubbermaid Inc.: Graco Chil...
# 61939                                                NaN
# 61943  (3/31/2011) BRAVO SPORTS: Thank you for transm...
# 61944                                                NaN
#
#       Associated Report Numbers
# 5                           NaN
# 18                          NaN
# 29                          NaN
# 35                          NaN
# 47                          NaN
# ...                         ...
# 61891                       NaN
# 61908                       NaN
# 61939                       NaN
# 61943                       NaN
# 61944                       NaN
#
# [3117 rows x 40 columns]

# %%
# Restricting to N sample reports to try and match them
N=100_000
reports_sample=reports.iloc[:N].copy()

# %%
reports_sample['best_brand_match_data']=reports_sample['Brand'].apply(lambda x: best_match(x,metadata['brand']))

# %%
reports_sample['Best Brand Match']=reports_sample['best_brand_match_data'].apply(lambda x : x[0] if x!=None else None)
reports_sample['Brand Match Score']=reports_sample['best_brand_match_data'].apply(lambda x : x[1] if x!=None else None)
reports_sample[['Brand','Best Brand Match','Brand Match Score']][reports_sample['Brand Match Score']>90]
# Out:
#                 Brand Best Brand Match  Brand Match Score
# 500      Fisher Price     Fisher Price         100.000000
# 518     Sesame street    Sesame Street          92.307692
# 592             Sassy            Sassy         100.000000
# 646    Kid Connection   Kid Connection         100.000000
# 671      Fisher Price     Fisher Price         100.000000
# ...               ...              ...                ...
# 61880     Baby Trend        Baby Trend          95.238095
# 61891           Circo            Circo         100.000000
# 61908           Graco            Graco         100.000000
# 61939        Yookidoo         Yookidoo         100.000000
# 61944          Target           Target         100.000000
#
# [912 rows x 3 columns]

# %%
reports_sample['best_title_match_data']=reports_sample['Product Description'].apply(lambda x: rf.process.extractOne(x,metadata['title'],scorer=rf.fuzz.ratio))

# %%
reports_sample['Best Desc. Match']=reports_sample['best_title_match_data'].apply(lambda x : x[0] if x!=None else None)
reports_sample['Desc. Match Score']=reports_sample['best_title_match_data'].apply(lambda x : x[1] if x!=None else None)
reports_sample[['Product Description','Best Desc. Match','Desc. Match Score']][reports_sample['Desc. Match Score']>80]
# Out:
#                                      Product Description  \
# 74                                        Bubble blaster
# 6398   Melissa & Doug Take-Along Tool Kit Wooden Cons...
# 7248              Daron Spirit Airlines Airport Play Set
# 23368                                   Hula Hair Barbie
# 24700                             Snoopy SnoCone Machine
# 24986                                  Umbrella stroller
# 27585                              Playhut: crawl n play
# 32795  Kidoozie Little Doctor Kit - Includes Stethosc...
# 37442                       Vtech Discovery Nursery Farm
# 43995                                 Crystal mining kit
# 44092                     Hohner Kids Toddler Music Band
# 44948              Playskool Mr. Potato Head Pirate Spud
# 46540                       Radio Flyer Little Red Wagon
# 48897                      Fisher Price Musical seahorse
# 49924      Little Tikes Adjust & Jam Basketball Set \r\n
# 50986                            Little Tikes Cozy Coupe
# 52772  Fisher-Price "Dora the Explorer My Talking Bac...
# 54772                                   Electronic Drums
# 55527                                        Barbie doll
# 56747        Fisher Price Laugh & Learn Learning Kitchen
# 57317           Little Tikes Little Champs Sports Center
# 57991                    Dexton 12' Great Plains Teepee
# 59181  Fisher-Price Little People Builders' Load 'n G...
# 59635                      Crayola Mini Twistable Crayon
# 61053                                    Crayola Crayons
# 61647                            Umbrella Style Stroller
#
#                                         Best Desc. Match  Desc. Match Score
# 74                                         Bubble Beater          81.481481
# 6398   Melissa &amp; Doug Take-Along Tool Kit Wooden ...          84.722222
# 7248              Daron Alaska Airlines Airport Play Set          84.210526
# 23368                              1996 Hula Hair Barbie          86.486486
# 24700                            Snoopy Sno Cone Machine          97.777778
# 24986                             Umbrella Doll Stroller          82.051282
# 27585                               Playhut Crawl N Play          82.926829
# 32795  Kidoozie Little Doctor Kit &ndash; Includes St...          95.238095
# 37442                     VTech - Discovery Nursery Farm          93.103448
# 43995                              4M Crystal Mining Kit          82.051282
# 44092                     Hohner Kids Toddler Music Band         100.000000
# 44948              Playskool Mr. Potato Head Pirate Spud         100.000000
# 46540                   Radio Flyer Little Red Toy Wagon          93.333333
# 48897                       Fisher-Price Musical Tea Set          80.701754
# 49924       Little Tikes Adjust &amp; Jam Basketball Set          91.954023
# 50986                            Little Tikes Cozy Coupe         100.000000
# 52772  Fisher-Price Dora the Explorer My Talking Back...          98.039216
# 54772                                   Electronic Craps          81.250000
# 55527                                        Barbie Pool          81.818182
# 56747  Fisher Price Laugh and Learn 2-in-1 Learning K...          88.421053
# 57317           Little Tikes Little Champs Sports Center         100.000000
# 57991                      Dexton 6' Great Plains Teepee          93.333333
# 59181  Fisher-Price Little People Builders Build 'n F...          80.701754
# 59635                    Crayola 30ct Twistables Crayons          83.333333
# 61053                               Crayola 48ct Crayons          85.714286
# 61647                             Umbrella Doll Stroller          84.444444

# %%
matches=reports_sample[['Product Description','Best Desc. Match','Brand','Best Brand Match','Desc. Match Score','Brand Match Score']][(reports_sample['Desc. Match Score']>70 )& (reports_sample['Brand Match Score']>70)]
matches.to_csv("potential_matches.csv")

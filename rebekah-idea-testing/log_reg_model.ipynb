# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %% [markdown]
# Load in the Data

# %%
train_df = pd.read_parquet('../train_final_v2.parquet')
val_df = pd.read_parquet('../validation_v2.parquet')

# %% [markdown]
# PreProcess the Data

# %%
# drop nonnumeric columns
train_df = train_df.drop(columns=['asin', 'title', 'incident_indices', 'component_no', 'avg_review_length_chars'])
val_df = val_df.drop(columns=['asin', 'title', 'incident_indices', 'component_no', 'avg_review_length_chars'])

# %%
train_df.columns[-10:]
# Out:
# Index(['embedding_380', 'embedding_381', 'embedding_382', 'embedding_383',
#        'mean_sentiment_score', 'mean_complaint_similarity',
#        'mean_shipping_similarity', 'max_complaint_similarity',
#        'shipping_similarity_at_max_complaint',
#        'sentiment_score_at_max_complaint'],
#       dtype='object')

# %%
# rename embed_{n} as summary_embedding_{n}
train_df.rename(columns={f"embed_{i}": f"summary_embedding_{i}" for i in range(384)}, inplace=True)
val_df.rename(columns={f"embed_{i}": f"summary_embedding_{i}" for i in range(384)}, inplace=True)

# rename embedding_{n} as reviewtext_embedding_{n}
train_df.rename(columns={f"embedding_{i}": f"reviewtext_embedding_{i}" for i in range(384)}, inplace=True)
val_df.rename(columns={f"embedding_{i}": f"reviewtext_embedding_{i}" for i in range(384)}, inplace=True)

# %%
# make target variable
y = train_df['match']
train_df = train_df.drop(columns=['match'])

# make target variable on validation set
y_val = val_df['match']
val_df = val_df.drop(columns=['match'])

# %%
# non-embedding features
begin_features = train_df.columns[:17].to_list()
end_features = train_df.columns[-6:].to_list()
non_embedding_features = begin_features + end_features

# %%
# categorical features
categorical_features = 'category'

# %% [markdown]
# EDA on Training Data

# %%
# correlation matrix for non-embedding features
train_df[begin_features[1:]+end_features].corr()
# Out:
#                                       missing_price  item_rank  avg_rating  \
# missing_price                              1.000000   0.396998   -0.073140
# item_rank                                  0.396998   1.000000   -0.104434
# avg_rating                                -0.073140  -0.104434    1.000000
# min_rating                                -0.083552  -0.285050    0.798802
# num_of_rating                             -0.073620  -0.194049    0.012130
# percent_positive                          -0.066451  -0.093928    0.928174
# percent_negative                           0.059721   0.087294   -0.902021
# avg_verified_reviewers                    -0.081448  -0.152149    0.107157
# min_date                                  -0.095101  -0.141977    0.030263
# max_date                                  -0.264436  -0.610756    0.065127
# product_lifespan                          -0.132477  -0.391730    0.025074
# num_bots_per_asin                         -0.071321  -0.140932    0.042107
# unique_reviewer_count                     -0.074876  -0.198323    0.012283
# avg_reviews_per_day                       -0.036504  -0.047640    0.028963
# reviews_per_product                       -0.073620  -0.194049    0.012130
# avg_review_length_words                    0.081616   0.137218   -0.118264
# mean_sentiment_score                      -0.058113  -0.109430    0.687557
# mean_complaint_similarity                  0.022490   0.055077   -0.275681
# mean_shipping_similarity                  -0.009731   0.006224   -0.188312
# max_complaint_similarity                  -0.087292  -0.362423   -0.179058
# shipping_similarity_at_max_complaint      -0.079638  -0.263053   -0.119813
# sentiment_score_at_max_complaint          -0.023271   0.015062    0.512590
#
#                                       min_rating  num_of_rating  \
# missing_price                          -0.083552      -0.073620
# item_rank                              -0.285050      -0.194049
# avg_rating                              0.798802       0.012130
# min_rating                              1.000000       0.072745
# num_of_rating                           0.072745       1.000000
# percent_positive                        0.740905       0.011818
# percent_negative                       -0.721813      -0.011596
# avg_verified_reviewers                  0.053863       0.002880
# min_date                               -0.074327      -0.124462
# max_date                                0.185872       0.164400
# product_lifespan                        0.248977       0.285043
# num_bots_per_asin                       0.056779       0.450656
# unique_reviewer_count                   0.074476       0.984984
# avg_reviews_per_day                     0.026985       0.009908
# reviews_per_product                     0.072745       1.000000
# avg_review_length_words                -0.074848       0.004978
# mean_sentiment_score                    0.551427       0.015685
# mean_complaint_similarity              -0.208528      -0.000582
# mean_shipping_similarity               -0.165705      -0.025495
# max_complaint_similarity                0.082436       0.306453
# shipping_similarity_at_max_complaint    0.034336       0.156577
# sentiment_score_at_max_complaint        0.328276      -0.073252
#
#                                       percent_positive  percent_negative  \
# missing_price                                -0.066451          0.059721
# item_rank                                    -0.093928          0.087294
# avg_rating                                    0.928174         -0.902021
# min_rating                                    0.740905         -0.721813
# num_of_rating                                 0.011818         -0.011596
# percent_positive                              1.000000         -0.801507
# percent_negative                             -0.801507          1.000000
# avg_verified_reviewers                        0.090413         -0.088357
# min_date                                      0.017897          0.002478
# max_date                                      0.052664         -0.031875
# product_lifespan                              0.027535         -0.031360
# num_bots_per_asin                             0.038415         -0.034859
# unique_reviewer_count                         0.011949         -0.011665
# avg_reviews_per_day                           0.027577         -0.024318
# reviews_per_product                           0.011818         -0.011596
# avg_review_length_words                      -0.106405          0.067935
# mean_sentiment_score                          0.643982         -0.648026
# mean_complaint_similarity                    -0.256183          0.257954
# mean_shipping_similarity                     -0.177249          0.197521
# max_complaint_similarity                     -0.164950          0.167599
# shipping_similarity_at_max_complaint         -0.111181          0.127898
# sentiment_score_at_max_complaint              0.477656         -0.485259
#
#                                       avg_verified_reviewers  min_date  \
# missing_price                                      -0.081448 -0.095101
# item_rank                                          -0.152149 -0.141977
# avg_rating                                          0.107157  0.030263
# min_rating                                          0.053863 -0.074327
# num_of_rating                                       0.002880 -0.124462
# percent_positive                                    0.090413  0.017897
# percent_negative                                   -0.088357  0.002478
# avg_verified_reviewers                              1.000000  0.328749
# min_date                                            0.328749  1.000000
# max_date                                            0.287161  0.517080
# product_lifespan                                   -0.105066 -0.639665
# num_bots_per_asin                                   0.013759 -0.056840
# unique_reviewer_count                               0.003110 -0.120588
# avg_reviews_per_day                                 0.033797  0.007576
# reviews_per_product                                 0.002880 -0.124462
# avg_review_length_words                            -0.336538 -0.294593
# mean_sentiment_score                                0.111373  0.077495
# mean_complaint_similarity                          -0.054559 -0.034053
# mean_shipping_similarity                            0.115028  0.129742
# max_complaint_similarity                           -0.045131 -0.191294
# shipping_similarity_at_max_complaint                0.080518 -0.021150
# sentiment_score_at_max_complaint                    0.084125  0.088985
#
#                                       max_date  ...  unique_reviewer_count  \
# missing_price                        -0.264436  ...              -0.074876
# item_rank                            -0.610756  ...              -0.198323
# avg_rating                            0.065127  ...               0.012283
# min_rating                            0.185872  ...               0.074476
# num_of_rating                         0.164400  ...               0.984984
# percent_positive                      0.052664  ...               0.011949
# percent_negative                     -0.031875  ...              -0.011665
# avg_verified_reviewers                0.287161  ...               0.003110
# min_date                              0.517080  ...              -0.120588
# max_date                              1.000000  ...               0.168201
# product_lifespan                      0.327161  ...               0.284181
# num_bots_per_asin                     0.113798  ...               0.449527
# unique_reviewer_count                 0.168201  ...               1.000000
# avg_reviews_per_day                   0.042645  ...               0.008450
# reviews_per_product                   0.164400  ...               0.984984
# avg_review_length_words              -0.252020  ...               0.004402
# mean_sentiment_score                  0.105689  ...               0.016062
# mean_complaint_similarity            -0.042916  ...              -0.000737
# mean_shipping_similarity              0.074228  ...              -0.025499
# max_complaint_similarity              0.275011  ...               0.311364
# shipping_similarity_at_max_complaint  0.250370  ...               0.159564
# sentiment_score_at_max_complaint      0.001538  ...              -0.074882
#
#                                       avg_reviews_per_day  \
# missing_price                                   -0.036504
# item_rank                                       -0.047640
# avg_rating                                       0.028963
# min_rating                                       0.026985
# num_of_rating                                    0.009908
# percent_positive                                 0.027577
# percent_negative                                -0.024318
# avg_verified_reviewers                           0.033797
# min_date                                         0.007576
# max_date                                         0.042645
# product_lifespan                                 0.029932
# num_bots_per_asin                                0.174477
# unique_reviewer_count                            0.008450
# avg_reviews_per_day                              1.000000
# reviews_per_product                              0.009908
# avg_review_length_words                         -0.078970
# mean_sentiment_score                             0.040883
# mean_complaint_similarity                        0.004279
# mean_shipping_similarity                         0.037245
# max_complaint_similarity                         0.025975
# shipping_similarity_at_max_complaint             0.047260
# sentiment_score_at_max_complaint                 0.029095
#
#                                       reviews_per_product  \
# missing_price                                   -0.073620
# item_rank                                       -0.194049
# avg_rating                                       0.012130
# min_rating                                       0.072745
# num_of_rating                                    1.000000
# percent_positive                                 0.011818
# percent_negative                                -0.011596
# avg_verified_reviewers                           0.002880
# min_date                                        -0.124462
# max_date                                         0.164400
# product_lifespan                                 0.285043
# num_bots_per_asin                                0.450656
# unique_reviewer_count                            0.984984
# avg_reviews_per_day                              0.009908
# reviews_per_product                              1.000000
# avg_review_length_words                          0.004978
# mean_sentiment_score                             0.015685
# mean_complaint_similarity                       -0.000582
# mean_shipping_similarity                        -0.025495
# max_complaint_similarity                         0.306453
# shipping_similarity_at_max_complaint             0.156577
# sentiment_score_at_max_complaint                -0.073252
#
#                                       avg_review_length_words  \
# missing_price                                        0.081616
# item_rank                                            0.137218
# avg_rating                                          -0.118264
# min_rating                                          -0.074848
# num_of_rating                                        0.004978
# percent_positive                                    -0.106405
# percent_negative                                     0.067935
# avg_verified_reviewers                              -0.336538
# min_date                                            -0.294593
# max_date                                            -0.252020
# product_lifespan                                     0.098915
# num_bots_per_asin                                   -0.026164
# unique_reviewer_count                                0.004402
# avg_reviews_per_day                                 -0.078970
# reviews_per_product                                  0.004978
# avg_review_length_words                              1.000000
# mean_sentiment_score                                -0.154008
# mean_complaint_similarity                            0.145193
# mean_shipping_similarity                            -0.163894
# max_complaint_similarity                             0.108662
# shipping_similarity_at_max_complaint                -0.117945
# sentiment_score_at_max_complaint                    -0.117160
#
#                                       mean_sentiment_score  \
# missing_price                                    -0.058113
# item_rank                                        -0.109430
# avg_rating                                        0.687557
# min_rating                                        0.551427
# num_of_rating                                     0.015685
# percent_positive                                  0.643982
# percent_negative                                 -0.648026
# avg_verified_reviewers                            0.111373
# min_date                                          0.077495
# max_date                                          0.105689
# product_lifespan                                  0.009356
# num_bots_per_asin                                 0.036150
# unique_reviewer_count                             0.016062
# avg_reviews_per_day                               0.040883
# reviews_per_product                               0.015685
# avg_review_length_words                          -0.154008
# mean_sentiment_score                              1.000000
# mean_complaint_similarity                        -0.220979
# mean_shipping_similarity                         -0.119002
# max_complaint_similarity                         -0.132655
# shipping_similarity_at_max_complaint             -0.067449
# sentiment_score_at_max_complaint                  0.722845
#
#                                       mean_complaint_similarity  \
# missing_price                                          0.022490
# item_rank                                              0.055077
# avg_rating                                            -0.275681
# min_rating                                            -0.208528
# num_of_rating                                         -0.000582
# percent_positive                                      -0.256183
# percent_negative                                       0.257954
# avg_verified_reviewers                                -0.054559
# min_date                                              -0.034053
# max_date                                              -0.042916
# product_lifespan                                      -0.000945
# num_bots_per_asin                                     -0.004807
# unique_reviewer_count                                 -0.000737
# avg_reviews_per_day                                    0.004279
# reviews_per_product                                   -0.000582
# avg_review_length_words                                0.145193
# mean_sentiment_score                                  -0.220979
# mean_complaint_similarity                              1.000000
# mean_shipping_similarity                               0.596503
# max_complaint_similarity                               0.651030
# shipping_similarity_at_max_complaint                   0.401651
# sentiment_score_at_max_complaint                      -0.186174
#
#                                       mean_shipping_similarity  \
# missing_price                                        -0.009731
# item_rank                                             0.006224
# avg_rating                                           -0.188312
# min_rating                                           -0.165705
# num_of_rating                                        -0.025495
# percent_positive                                     -0.177249
# percent_negative                                      0.197521
# avg_verified_reviewers                                0.115028
# min_date                                              0.129742
# max_date                                              0.074228
# product_lifespan                                     -0.076580
# num_bots_per_asin                                     0.005951
# unique_reviewer_count                                -0.025499
# avg_reviews_per_day                                   0.037245
# reviews_per_product                                  -0.025495
# avg_review_length_words                              -0.163894
# mean_sentiment_score                                 -0.119002
# mean_complaint_similarity                             0.596503
# mean_shipping_similarity                              1.000000
# max_complaint_similarity                              0.356591
# shipping_similarity_at_max_complaint                  0.685962
# sentiment_score_at_max_complaint                     -0.094425
#
#                                       max_complaint_similarity  \
# missing_price                                        -0.087292
# item_rank                                            -0.362423
# avg_rating                                           -0.179058
# min_rating                                            0.082436
# num_of_rating                                         0.306453
# percent_positive                                     -0.164950
# percent_negative                                      0.167599
# avg_verified_reviewers                               -0.045131
# min_date                                             -0.191294
# max_date                                              0.275011
# product_lifespan                                      0.458159
# num_bots_per_asin                                     0.185574
# unique_reviewer_count                                 0.311364
# avg_reviews_per_day                                   0.025975
# reviews_per_product                                   0.306453
# avg_review_length_words                               0.108662
# mean_sentiment_score                                 -0.132655
# mean_complaint_similarity                             0.651030
# mean_shipping_similarity                              0.356591
# max_complaint_similarity                              1.000000
# shipping_similarity_at_max_complaint                  0.606069
# sentiment_score_at_max_complaint                     -0.255365
#
#                                       shipping_similarity_at_max_complaint  \
# missing_price                                                    -0.079638
# item_rank                                                        -0.263053
# avg_rating                                                       -0.119813
# min_rating                                                        0.034336
# num_of_rating                                                     0.156577
# percent_positive                                                 -0.111181
# percent_negative                                                  0.127898
# avg_verified_reviewers                                            0.080518
# min_date                                                         -0.021150
# max_date                                                          0.250370
# product_lifespan                                                  0.248189
# num_bots_per_asin                                                 0.132267
# unique_reviewer_count                                             0.159564
# avg_reviews_per_day                                               0.047260
# reviews_per_product                                               0.156577
# avg_review_length_words                                          -0.117945
# mean_sentiment_score                                             -0.067449
# mean_complaint_similarity                                         0.401651
# mean_shipping_similarity                                          0.685962
# max_complaint_similarity                                          0.606069
# shipping_similarity_at_max_complaint                              1.000000
# sentiment_score_at_max_complaint                                 -0.145047
#
#                                       sentiment_score_at_max_complaint
# missing_price                                                -0.023271
# item_rank                                                     0.015062
# avg_rating                                                    0.512590
# min_rating                                                    0.328276
# num_of_rating                                                -0.073252
# percent_positive                                              0.477656
# percent_negative                                             -0.485259
# avg_verified_reviewers                                        0.084125
# min_date                                                      0.088985
# max_date                                                      0.001538
# product_lifespan                                             -0.096860
# num_bots_per_asin                                            -0.018096
# unique_reviewer_count                                        -0.074882
# avg_reviews_per_day                                           0.029095
# reviews_per_product                                          -0.073252
# avg_review_length_words                                      -0.117160
# mean_sentiment_score                                          0.722845
# mean_complaint_similarity                                    -0.186174
# mean_shipping_similarity                                     -0.094425
# max_complaint_similarity                                     -0.255365
# shipping_similarity_at_max_complaint                         -0.145047
# sentiment_score_at_max_complaint                              1.000000
#
# [22 rows x 22 columns]

# %%
# correlation matrix for all features
train_df[train_df.columns[1:]].corr()
# Out:
#                                       missing_price  item_rank  avg_rating  \
# missing_price                              1.000000   0.396998   -0.073140
# item_rank                                  0.396998   1.000000   -0.104434
# avg_rating                                -0.073140  -0.104434    1.000000
# min_rating                                -0.083552  -0.285050    0.798802
# num_of_rating                             -0.073620  -0.194049    0.012130
# ...                                             ...        ...         ...
# mean_complaint_similarity                  0.022490   0.055077   -0.275681
# mean_shipping_similarity                  -0.009731   0.006224   -0.188312
# max_complaint_similarity                  -0.087292  -0.362423   -0.179058
# shipping_similarity_at_max_complaint      -0.079638  -0.263053   -0.119813
# sentiment_score_at_max_complaint          -0.023271   0.015062    0.512590
#
#                                       min_rating  num_of_rating  \
# missing_price                          -0.083552      -0.073620
# item_rank                              -0.285050      -0.194049
# avg_rating                              0.798802       0.012130
# min_rating                              1.000000       0.072745
# num_of_rating                           0.072745       1.000000
# ...                                          ...            ...
# mean_complaint_similarity              -0.208528      -0.000582
# mean_shipping_similarity               -0.165705      -0.025495
# max_complaint_similarity                0.082436       0.306453
# shipping_similarity_at_max_complaint    0.034336       0.156577
# sentiment_score_at_max_complaint        0.328276      -0.073252
#
#                                       percent_positive  percent_negative  \
# missing_price                                -0.066451          0.059721
# item_rank                                    -0.093928          0.087294
# avg_rating                                    0.928174         -0.902021
# min_rating                                    0.740905         -0.721813
# num_of_rating                                 0.011818         -0.011596
# ...                                                ...               ...
# mean_complaint_similarity                    -0.256183          0.257954
# mean_shipping_similarity                     -0.177249          0.197521
# max_complaint_similarity                     -0.164950          0.167599
# shipping_similarity_at_max_complaint         -0.111181          0.127898
# sentiment_score_at_max_complaint              0.477656         -0.485259
#
#                                       avg_verified_reviewers  min_date  \
# missing_price                                      -0.081448 -0.095101
# item_rank                                          -0.152149 -0.141977
# avg_rating                                          0.107157  0.030263
# min_rating                                          0.053863 -0.074327
# num_of_rating                                       0.002880 -0.124462
# ...                                                      ...       ...
# mean_complaint_similarity                          -0.054559 -0.034053
# mean_shipping_similarity                            0.115028  0.129742
# max_complaint_similarity                           -0.045131 -0.191294
# shipping_similarity_at_max_complaint                0.080518 -0.021150
# sentiment_score_at_max_complaint                    0.084125  0.088985
#
#                                       max_date  ...  reviewtext_embedding_380  \
# missing_price                        -0.264436  ...                 -0.036883
# item_rank                            -0.610756  ...                 -0.029441
# avg_rating                            0.065127  ...                  0.163365
# min_rating                            0.185872  ...                  0.104893
# num_of_rating                         0.164400  ...                 -0.018178
# ...                                        ...  ...                       ...
# mean_complaint_similarity            -0.042916  ...                 -0.141228
# mean_shipping_similarity              0.074228  ...                 -0.141759
# max_complaint_similarity              0.275011  ...                 -0.124370
# shipping_similarity_at_max_complaint  0.250370  ...                 -0.119150
# sentiment_score_at_max_complaint      0.001538  ...                  0.118600
#
#                                       reviewtext_embedding_381  \
# missing_price                                         0.026650
# item_rank                                            -0.040925
# avg_rating                                            0.120406
# min_rating                                            0.091108
# num_of_rating                                         0.009791
# ...                                                        ...
# mean_complaint_similarity                            -0.278807
# mean_shipping_similarity                             -0.089801
# max_complaint_similarity                             -0.195989
# shipping_similarity_at_max_complaint                 -0.079572
# sentiment_score_at_max_complaint                      0.120474
#
#                                       reviewtext_embedding_382  \
# missing_price                                         0.049814
# item_rank                                            -0.000166
# avg_rating                                           -0.088510
# min_rating                                           -0.052749
# num_of_rating                                         0.025425
# ...                                                        ...
# mean_complaint_similarity                             0.173835
# mean_shipping_similarity                              0.059298
# max_complaint_similarity                              0.153375
# shipping_similarity_at_max_complaint                  0.054777
# sentiment_score_at_max_complaint                     -0.082659
#
#                                       reviewtext_embedding_383  \
# missing_price                                         0.037874
# item_rank                                            -0.007145
# avg_rating                                           -0.053543
# min_rating                                           -0.015424
# num_of_rating                                         0.037029
# ...                                                        ...
# mean_complaint_similarity                             0.307109
# mean_shipping_similarity                              0.208330
# max_complaint_similarity                              0.237633
# shipping_similarity_at_max_complaint                  0.159591
# sentiment_score_at_max_complaint                     -0.076829
#
#                                       mean_sentiment_score  \
# missing_price                                    -0.058113
# item_rank                                        -0.109430
# avg_rating                                        0.687557
# min_rating                                        0.551427
# num_of_rating                                     0.015685
# ...                                                    ...
# mean_complaint_similarity                        -0.220979
# mean_shipping_similarity                         -0.119002
# max_complaint_similarity                         -0.132655
# shipping_similarity_at_max_complaint             -0.067449
# sentiment_score_at_max_complaint                  0.722845
#
#                                       mean_complaint_similarity  \
# missing_price                                          0.022490
# item_rank                                              0.055077
# avg_rating                                            -0.275681
# min_rating                                            -0.208528
# num_of_rating                                         -0.000582
# ...                                                         ...
# mean_complaint_similarity                              1.000000
# mean_shipping_similarity                               0.596503
# max_complaint_similarity                               0.651030
# shipping_similarity_at_max_complaint                   0.401651
# sentiment_score_at_max_complaint                      -0.186174
#
#                                       mean_shipping_similarity  \
# missing_price                                        -0.009731
# item_rank                                             0.006224
# avg_rating                                           -0.188312
# min_rating                                           -0.165705
# num_of_rating                                        -0.025495
# ...                                                        ...
# mean_complaint_similarity                             0.596503
# mean_shipping_similarity                              1.000000
# max_complaint_similarity                              0.356591
# shipping_similarity_at_max_complaint                  0.685962
# sentiment_score_at_max_complaint                     -0.094425
#
#                                       max_complaint_similarity  \
# missing_price                                        -0.087292
# item_rank                                            -0.362423
# avg_rating                                           -0.179058
# min_rating                                            0.082436
# num_of_rating                                         0.306453
# ...                                                        ...
# mean_complaint_similarity                             0.651030
# mean_shipping_similarity                              0.356591
# max_complaint_similarity                              1.000000
# shipping_similarity_at_max_complaint                  0.606069
# sentiment_score_at_max_complaint                     -0.255365
#
#                                       shipping_similarity_at_max_complaint  \
# missing_price                                                    -0.079638
# item_rank                                                        -0.263053
# avg_rating                                                       -0.119813
# min_rating                                                        0.034336
# num_of_rating                                                     0.156577
# ...                                                                    ...
# mean_complaint_similarity                                         0.401651
# mean_shipping_similarity                                          0.685962
# max_complaint_similarity                                          0.606069
# shipping_similarity_at_max_complaint                              1.000000
# sentiment_score_at_max_complaint                                 -0.145047
#
#                                       sentiment_score_at_max_complaint
# missing_price                                                -0.023271
# item_rank                                                     0.015062
# avg_rating                                                    0.512590
# min_rating                                                    0.328276
# num_of_rating                                                -0.073252
# ...                                                                ...
# mean_complaint_similarity                                    -0.186174
# mean_shipping_similarity                                     -0.094425
# max_complaint_similarity                                     -0.255365
# shipping_similarity_at_max_complaint                         -0.145047
# sentiment_score_at_max_complaint                              1.000000
#
# [790 rows x 790 columns]

# %%
# filter the correlation matrix to see which features have higher than |0.5| correlation
feature_corr_matrix = train_df[train_df.columns[1:]].corr()

mask = np.triu(np.ones_like(feature_corr_matrix, dtype=bool))

high_corr = feature_corr_matrix.where(~mask).stack().reset_index()
high_corr.columns = ['Feature_1', 'Feature_2', 'Correlation']

pos_corr_result = (high_corr[high_corr['Correlation'] >= 0.5])

pos_corr_result = pos_corr_result.sort_values(by='Correlation', ascending=False)

# Show Results of the filter
pos_corr_result
# Out:
#                    Feature_1              Feature_2  Correlation
# 95       reviews_per_product          num_of_rating     1.000000
# 70     unique_reviewer_count          num_of_rating     0.984984
# 103      reviews_per_product  unique_reviewer_count     0.984984
# 12          percent_positive             avg_rating     0.928174
# 5                 min_rating             avg_rating     0.798802
# ...                      ...                    ...          ...
# 27099  summary_embedding_217   summary_embedding_55     0.500853
# 74490  summary_embedding_370  summary_embedding_169     0.500726
# 44367  summary_embedding_282   summary_embedding_98     0.500573
# 67578  summary_embedding_352   summary_embedding_34     0.500145
# 9780   summary_embedding_124   summary_embedding_34     0.500031
#
# [452 rows x 3 columns]

# %%
# top 10 positively correlated features
# need to drop reviews_per_product or num_of_rating
pos_corr_result.head(10)
# Out:
#                                Feature_1              Feature_2  Correlation
# 95                   reviews_per_product          num_of_rating     1.000000
# 70                 unique_reviewer_count          num_of_rating     0.984984
# 103                  reviews_per_product  unique_reviewer_count     0.984984
# 12                      percent_positive             avg_rating     0.928174
# 5                             min_rating             avg_rating     0.798802
# 6390                summary_embedding_97   summary_embedding_46     0.751139
# 13                      percent_positive             min_rating     0.740905
# 311650  sentiment_score_at_max_complaint   mean_sentiment_score     0.722845
# 6378                summary_embedding_97   summary_embedding_34     0.713454
# 1941                summary_embedding_46   summary_embedding_34     0.701901

# %%
# negative correlation between features
neg_corr_result = (high_corr[high_corr['Correlation'] <= -0.5])

neg_corr_result = neg_corr_result.sort_values(by='Correlation', ascending=True)

# Show Results of the filter
neg_corr_result
# Out:
#                        Feature_1                 Feature_2  Correlation
# 17              percent_negative                avg_rating    -0.902021
# 194280  reviewtext_embedding_223  reviewtext_embedding_127    -0.897861
# 28584      summary_embedding_223     summary_embedding_127    -0.838924
# 20              percent_negative          percent_positive    -0.801507
# 18              percent_negative                min_rating    -0.721813
# ...                          ...                       ...          ...
# 1147        summary_embedding_32       summary_embedding_3    -0.500507
# 63018      summary_embedding_339     summary_embedding_167    -0.500483
# 41347      summary_embedding_272       summary_embedding_3    -0.500206
# 41091      summary_embedding_271      summary_embedding_34    -0.500143
# 9535       summary_embedding_122      summary_embedding_66    -0.500006
#
# [455 rows x 3 columns]

# %%
# top 10 negatively correlated features
neg_corr_result.head(10)
# Out:
#                        Feature_1                 Feature_2  Correlation
# 17              percent_negative                avg_rating    -0.902021
# 194280  reviewtext_embedding_223  reviewtext_embedding_127    -0.897861
# 28584      summary_embedding_223     summary_embedding_127    -0.838924
# 20              percent_negative          percent_positive    -0.801507
# 18              percent_negative                min_rating    -0.721813
# 70187      summary_embedding_359      summary_embedding_46    -0.705972
# 53037      summary_embedding_310      summary_embedding_46    -0.705865
# 258136  reviewtext_embedding_319   avg_review_length_words    -0.701248
# 53088      summary_embedding_310      summary_embedding_97    -0.700853
# 59109      summary_embedding_328      summary_embedding_97    -0.690237

# %% [markdown]
# Make a Model

# %%
# initialize logistic regression model without penalty
log_reg = LogisticRegression(penalty=None)

# %%
train_df['product_lifespan'] = train_df['product_lifespan'].dt.days
val_df['product_lifespan'] = val_df['product_lifespan'].dt.days
categorical_cols = train_df.select_dtypes(include=['object', 'category']).columns.tolist()
numeric_cols = train_df.select_dtypes(include=['number']).columns.tolist()

# %%
# Combine with ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ]
)

# Full pipeline
model_pipeline = Pipeline([
    ('preprocessing', preprocessor),
    ('scale', StandardScaler()),
    ('logreg', log_reg)])

# %%
model_pipeline.fit(train_df, y.values)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['item_rank', 'avg_rating',
#                                                    'min_rating',
#                                                    'num_of_rating',
#                                                    'percent_positive',
#                                                    'percent_negative',
#                                                    'avg_verified_reviewers',
#                                                    'product_lifespan',
#                                                    'num_bots_per_asin',
#                                                    'unique_reviewer_count',
#                                                    'avg_reviews_per_day',
#                                                    'reviews_per_product',
#                                                    'avg_review_length_words',
#                                                    'summary_e...
#                                                    'summary_embedding_7',
#                                                    'summary_embedding_8',
#                                                    'summary_embedding_9',
#                                                    'summary_embedding_10',
#                                                    'summary_embedding_11',
#                                                    'summary_embedding_12',
#                                                    'summary_embedding_13',
#                                                    'summary_embedding_14',
#                                                    'summary_embedding_15',
#                                                    'summary_embedding_16', ...]),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['category'])])),
#                 ('scale', StandardScaler()),
#                 ('logreg', LogisticRegression(penalty=None))])

# %%
preds = model_pipeline.predict(val_df)

# %%
from sklearn.metrics import root_mean_squared_error
root_mean_squared_error(y_val, preds)
# Out:
# 0.08540393920399116

# %% [markdown]
# # Documentation for `SimilarityScore.ipynb`
#
# ## Overview
# This notebook computes semantic similarity scores between Amazon product reviews and reference complaint or shipping-related sentences using sentence embeddings. It also incorporates sentiment analysis to improve the precision of similarity-based filtering. The resulting features are aggregated at the product level.
#
# ## Main Steps
#
# 1.  Loads Amazon reviews with precomputed embeddings from `amazon_reviews_with_embeddings.parquet` (generated by `EmbeddingCalculationReviewText.ipynb`).
#
# 2.  Computes the similarity scores of the review text with a collection of reference complaint sentences (`sentences_complaint.pkl`). This uses the `all-MiniLM-L6-v2`. We also calculate the similarity score between review text and a set of shipping-related complaint sentences.
#
# 3. We use a sentiment classifier (`distilbert-base-uncased-finetuned-sst-2-english`) to compute sentiment scores for each review. To reduce false positives, we filter out reviews with high similarity but positive sentiment to the complaint sentences, in order to reduce false positives.
#
# 4. We aggregates mean and maximum similarity and sentiment scores per ASIN, and compute weighted and mean review embeddings per ASIN, giving more weight to negative reviews.
#
# 5. We then save the final product-level features and embeddings to `Data/review_features_df.pkl`.
#
# ## Input Files
#
# - `amazon_reviews_with_embeddings.parquet` (Amazon reviews with sentence embeddings)
# - `sentences_complaint.pkl` (reference complaint sentences)
#
# ## Output Files
#
# - `amazon_reviews_with_similarity_scores.parquet` (reviews with similarity scores)
# - `amazon_reviews_with_sim_sent_scores.parquet` (reviews with similarity and sentiment scores)
# - `../Data/review_features_df.pkl` (aggregated product-level features and embeddings)

# %%
import pandas as pd
import numpy as np
import re
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Load Amazon Reviews Data With Embeddings

# %%
amazon_df = pd.read_parquet("amazon_reviews_with_embeddings.parquet")

# %%
amazon_df.shape
amazon_df.columns
# Out:
# Index(['overall', 'vote', 'verified', 'reviewTime', 'reviewerID', 'asin',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'image',
#        'style', 'review_len_words', 'review_len_chars', 'reviewText_clean',
#        'embedding'],
#       dtype='object')

# %% [markdown]
# ## Loading Model `all-MiniLM-L6-v2`

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2', device='cuda')
model.max_seq_length = 256
# Out:
# C:\Users\Betul\anaconda3\envs\pytorch_env\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
def clean_text(text):
    text = str(text).strip()
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'<.*?>', '', text)
    return text

# %%
def add_similarity_scores(amazon_df, sentences, model, similarity_column):
    # Clean and encode input sentences
    cleaned_sentences = [clean_text(s) for s in sentences if pd.notnull(s)]
    sentence_embeddings = model.encode(cleaned_sentences)
    mean_embedding = np.mean(sentence_embeddings, axis=0)

    # Create a copy to avoid modifying original DataFrame
    df = amazon_df.copy()

    # Initialize similarity column
    df[similarity_column] = None

    # Process non-null embeddings
    valid_mask = df['embedding'].notnull()
    if valid_mask.sum() == 0:
        return df  # No valid embeddings

    embedding_matrix = np.vstack(df.loc[valid_mask, 'embedding'])
    similarities = cosine_similarity(embedding_matrix, [mean_embedding]).flatten()
    df.loc[valid_mask, similarity_column] = similarities

    return df

# %%
def print_top_similar_reviews(df, score_column, text_column='reviewText', top_n=20):

    # Sort and get top reviews
    top_reviews = df.sort_values(by=score_column, ascending=False).head(top_n)

    # Print them nicely
    for i, (_, row) in enumerate(top_reviews.iterrows(), 1):
        print(f"--- Review {i} ---")
        print(f"Similarity Score: {row[score_column]:.4f}")
        print(f"{text_column}:\n{row[text_column]}\n")

# %% [markdown]
# ### Try Similarity Scores With Five Complaint Sentences

# %%
sentence31 = "I began experiencing issues shortly after using the product. There was a strange fume that caused discomfort, and a burning sensation followed. Upon closer inspection, I noticed parts that seemed cracked or wet, possibly from a toxic or excessive chemical leak. My doctor advised a checkup after I developed irritation, and the specialist mentioned possible exposure to a carcinogen. I also saw rusted metal and a joint that had become loose, potentially leading to an internal hazard. It even skidded on smooth surfaces, and at one point got wedged under a cabinet. I sent a pic to support, but the response was delayed. This whole process was uncomfortable, and honestly, the product's failure left me feeling unsafe and frustrated."
sentence31 = "I want to issue a serious warning about this product. It posed multiple hazards and could potentially be dangerous under normal use. While following all instructions, I experienced a rash that later turned infected, possibly due to a contaminated coating or poor manufacturing. The item had visible fragment damage and arrived from a questionable batch, emitting a fishy smell that didn’t seem okay. During use, a piece suddenly split, and I nearly tripped, injuring my shoulder. The situation was upsetting enough that I contacted an attorney, and I’m currently investigating whether a teratogen or other harmful substance was involved. My doctor mentioned GI issues could be linked. I also noticed sharp barbs near the attachment point, and the vinyl edges were poorly sealed. The unit would shake uncontrollably on acceleration, making operation unsafe. My eardrum felt strained from a sudden boom sound, and I had to schedule an extraction due to an object blocking my nostril. Honestly, the experience has been a complete disaster, and it ought to be declared unfit for sale. I’ve saved the product, the decal, and even the knife used to open the package in case I need to settle this through legal means. I’d strongly advise others to avoid this item entirely. It's not just poorly made, it’s lethality without warning."
sentence31 = "After purchasing this item, I had a truly unsettling experience. I was preparing dinner and attempted to remove the lid, but it was jammed so tightly I had to tilt and pry it off, which led to a sudden faceplant as the container slipped. I pinched my hand in the process and spilled part of the frozen contents across the floor. The included packet of seasoning smelled bitter, and after cooking, I noticed the meat had a strange misshapen texture and an off taste. Within hours, I felt sick, with abdominal cramping and redness forming around my mouth — likely an allergic reaction. I checked the use-by date and realized it had passed. I’ve since submitted a complaint and requested the product be replaced, but the process has been frustrating. I feel this could have been a deadlydanger for someone with more severe allergies. The entire situation was terrifying — from the injury while opening it to the symptoms that followed. Honestly, the quality and safety of this product are unacceptable."
sentence13 = "I had an awful experience with this product and want to warn others. It was advertised as sturdy and safe, but that’s far from the truth. Shortly after unboxing, I noticed parts were rusted and chipped, and some metal components had started to flake. While using it, the mechanism suddenly jammed, and when I tried to adjust it, it abruptly collapsed, causing me to injure my ankle. The pain was intense enough that I later had to visit a neurologist due to nerve issues from the scrapes and swelling. Even worse, the smell of smoke emerged after brief use, and I had to immediately unplug it. I contacted a representative, but they simply told me to return the item without offering support or concern. It felt inevitable that someone would get seriously hurt using this. At one point, I even dropped it near my child, and one of the sharp parts nearly slit the surface of our posterior cabinet. I’m honestly afraid of using anything similar again — the risk of a crash or breakdown is just too high. Products like this should undergo more thorough safety checks before being sold."
sentence17 = "I had a terrible experience that left me deeply disappointed and honestly a little shaken. After just a few uses, the product began to malfunction, and a sharp edge cut my finger while trying to disassemble it for cleaning. The injury bled more than expected, and I had to visit emergency care. I was told the wound might result in a permanent scar. Even before that, parts had become sticky, and the material gave off a scenty, almost petroleum-like odor that irritated my skin. Shortly after storing it, a piece shattered near the axle, nearly hitting me in the chest. It’s shocking that a product with such volatile materials is allowed on the market. I’ve now removed it completely from my home and am trying to get it recalled. I wouldn’t wish this on anyone — it’s a threat to safety, and the company should take professional responsibility for the painful consequences I’ve endured. I’ll be much more cautious in the future and urge others to stay away."

sentences = [sentence31, sentence31, sentence31, sentence13, sentence17]

# %%
amazon_df = add_similarity_scores(amazon_df, sentences, model, "complaint_similarity5")
# Out:
# C:\Users\Betul\anaconda3\envs\pytorch_env\Lib\site-packages\transformers\models\bert\modeling_bert.py:439: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(

# %%
print_top_similar_reviews(amazon_df, score_column="complaint_similarity5", text_column='reviewText', top_n=20)
# Out:
# --- Review 1 ---
# Similarity Score: 0.5947
# reviewText:
# Beware of this product.  I opened it out of the package and I'm not sure if they treated the material for something or what but I immediately had an asthma attack and my eyes welled up and I couldn't breath I had to take multiple medications to calm my reaction down.  When my husband got home I had him check it out and he had the same problem.  We bought this for my son's birthday so we didn't open it until after the 30 day return policy was up so now I'm stuck with this thing that will most likely end up in the trash.  Do not buy this for small children especially if they have allergies or asthma.  Very strong chemical smell.  And there is no warning for this on the box.  Very disappointed especially after getting it out and my children seeing it, then having to throw it outside.
#
# --- Review 2 ---
# Similarity Score: 0.5880
# reviewText:
# My son was just hospitalized by this I'm very upset and I will be doing everything I can to sue and have this removed from shelf everywhere this is no joke and is very harmful and deadly please be more careful using this product.
#
# --- Review 3 ---
# Similarity Score: 0.5867
# reviewText:
# The package was broken  and pieces were everywhere in the envelope and on the back it actually said could be poison and could effect health.  It was horrible. My husband threw it away instead of returning the product
#
# --- Review 4 ---
# Similarity Score: 0.5858
# reviewText:
# Product damaged and unusable.
#
# --- Review 5 ---
# Similarity Score: 0.5794
# reviewText:
# I ignored the several reviews that also stated they received theirs damaged, thought it was priced ok for a wood product. My box was thin but not damaged the product itself was damaged in several areas see photos, the aroma from the game is awful it filled a 3k foot house in minutes it's that strong. As others have said when dropping chips it's very LOUD. Dropping or removing the chips requires you to remove and lift up on the bottom wood bar and it sticks so not easy but not all that hard but for younger children it would be a bigger challenge. I have attempted to reach customer service left voicemail after voicemail but still no response as to what they want to do with this damaged product. Till you start seeing great positive reviews that reflect the negatives above I would stay far away from this product and possible company.
# *Update-I received a phone call from Kevin at Yardgames he addressed my concerns regarding the damaged item, packaging and the smell that radiates from this product, they have a newer version that they are now sending out, they are addressing the packaging and will address the coating of the product to prevent this smell in upcoming products. I feel more confident knowing this.
# *Update #3-received my 2nd one today and it was honestly packaged even better, but still damaged same spots. Customer service Kevin has been awesome during this process.
# *Update I received my 3rd one and this one came in perfect, the packing was greatly improved and this is a HUGE Hit in my training and Team Building exercises within our company. I'm sure this company will begin receiving additional orders based on how fun this is to play. The Customer Service is and has been extremely helpful during this process and I am looking forward to purchasing additional games to add to my collection.
#
# --- Review 6 ---
# Similarity Score: 0.5793
# reviewText:
# I bought this product last year for a Halloween party for kids aging from 7-11.  The kids did have fun with it, however, two kids at the party had a reaction to the bubbles.  One girls face was itching and turning red in spots where the bubble hit her face and more alarming was that another boy had what looked like a chemical burn (almost blistering) on his cheek that burned.  I washed his face immediately.  I did not take him to the dr. because it wasn't getting larger and seemed to be getting better in a few days I believe it was.  But there was no warning of this.  I left a message on the companys answering machine and they called me the first thing in the morning that they opened.  They said they never heard anything like this because it is used worldwide.  I also sent them a picture of the boys cheek that was affected.  They were very good about this and had me return the bottle and paid the purchase price and the shipping for returning it.  I was hoping by now they would have put something up of some warning, maybe because I didn't go to the dr. that is why.  I showed a few nurses at church his face, and they agreed that it looked like a chemical burn.  I just want anyone out there to be careful of this product if they choose to use it.  The kids did love to play with it.  Also one of my mistakes when they played with it, is to make sure you have florescent black lights not just a black lightbulb...at least I had one flourescent bulb.  Great product if there is no side effects.
#
# --- Review 7 ---
# Similarity Score: 0.5738
# reviewText:
# This is probably the worst item I have bought on Amazon. It smells really toxic and it's poorly made. I washed it, let it air out for two weeks but the toxic chemical smell was still very strong. Two of the pieces cracked while just sitting there being aired out. I hardly ever write reviews but felt I should for this junk.
#
# --- Review 8 ---
# Similarity Score: 0.5738
# reviewText:
# This is probably the worst item I have bought on Amazon. It smells really toxic and it's poorly made. I washed it, let it air out for two weeks but the toxic chemical smell was still very strong. Two of the pieces cracked while just sitting there being aired out. I hardly ever write reviews but felt I should for this junk.
#
# --- Review 9 ---
# Similarity Score: 0.5696
# reviewText:
# Horrible condition. Extremely upset with this product.
#
# --- Review 10 ---
# Similarity Score: 0.5682
# reviewText:
# I am very upset with this product. I purchased one as a gift and the nose was completely botched. One side was entirely too big and it was completely disproportionate and clearly defective. I am shocked something of this low quality would be sent out. Absolutely saddened by the fact that my gift was ruined.
# picture: [...]
#
# --- Review 11 ---
# Similarity Score: 0.5680
# reviewText:
# I contacted the company directly to report a product that almost caused a fire and burned me, and they didn't care. They wouldn't send me a label to ship it back directly and had no interest in resolving a major product defect and potential fire hazard.
#
# --- Review 12 ---
# Similarity Score: 0.5673
# reviewText:
# I received an item that looks like it was used and abused for no less than two years. It was so nasty that someone threw it out as a safety precaution (feces), so I can't even return it.
#
# --- Review 13 ---
# Similarity Score: 0.5606
# reviewText:
# The container was cracked, and the contents spilled all over the inside of the packing envelope. Unable to use this item and unable to return. There is no mechanism for filing a complaint or getting a replacement without returning this item, which is impossible. Highly satisfied.
#
# --- Review 14 ---
# Similarity Score: 0.5571
# reviewText:
# This was seriously one of the worst products I've ever bought from Amazon. I'm so mad. I bought this as a joke for my boss. First of all it's tiny, second of all it had the lid taped down with packing tape and when you peel it off it rips the cardboard outside, thirdly there was a huge label that it was a prank on the side that again ripped it. When we opened it NOTHING POPPED OUT! It made a pathetic little whine sound and a tiny think slowly crept out like it was waking up. Honestly I'm going to get refunded because this was a waste of my time and money. So mad.
#
# --- Review 15 ---
# Similarity Score: 0.5562
# reviewText:
# Exploded in my daughters face.  After only a few minutes of playing with it the stick ruptured in the middle and sprayed glow chemicals directly into my daughters face, it got into her eyes and mouth, causing pain and terrifying all of us. Do not buy this hazardous product.
#
# --- Review 16 ---
# Similarity Score: 0.5550
# reviewText:
# I am so upset. I bought this for my daughters birthday.  This is the only thing I got for her. Imagine her opening it and just about every piece looked like it had been chewed on. I hope I can trade it out but whoever packed this had to know about the damage. Impossible to miss. It did arrive quickly.
#
# --- Review 17 ---
# Similarity Score: 0.5520
# reviewText:
# Update: I was contacted by a Melissa & Doug rep about this. The refund went through fine on prime, but they wanted to make me happy. They offered to send a new one that I accepted and for which I was grateful. But this one was exactly the same save 2 things. 1. No mustache (same discoloration on body) 2. No plastic wrap around the item (as in packaging). If I gave this item to the intended recipient in no packaging at all it would look like a hand-me-down. If I used saran wrap to wrap around the box, it's gonna look bad. The second item also left loose splinters on the table just from me lifting it out of the box, and recall that there was no packaging to open. To be fair, their customer service is helly top notch, but the item is only okay IMO.
#
# Original review: It was ok, but not like the pic. The one I received was totally discolored. The middle part of the animal was very dark brown and the paint was sloppy. On his face there was wood flaws or dark paint that made it look like a dirty mustache. The wood edges appeared to be rough as well. The box looked old and faded. This was going to be a gift, but I'd have been embarrassed to gift this so I'm returning it.
#
# --- Review 18 ---
# Similarity Score: 0.5516
# reviewText:
# Product was severely damaged.
#
# --- Review 19 ---
# Similarity Score: 0.5500
# reviewText:
# Product was damaged, with scratches,abrasions, & was chipped in several spots.
#
# --- Review 20 ---
# Similarity Score: 0.5489
# reviewText:
# One day, my child took the can of the toy, to give me to eat, my lips touched the can surface, I do not mind.
# Inadvertently, my tongue touched my lips, the results of the tongue is a sense of thorns, and bitter taste.
# I immediately discarded the canned toy, however, this uncomfortable feeling lasted for a whole day.
# That night, I was depressed, so that my child access to such unsafe toys.
# The next morning, I looked at other toys and found that some of my children have been bite off paint, and I'm not sure how much he has eaten.
# I explained my insecurity to my child, and then told him that we had to throw it away.
# Even if the product does not let me satisfied, I rarely give a negative evaluation, but this product, poor quality, unsafe, and should not let the child contact.

# %% [markdown]
# ## Use More Sentences To Find The Cosine Similarities

# %%
# Load sentences:
import pickle

with open("sentences_complaint.pkl", "rb") as f:
    sentences_complaint = pickle.load(f)

# %%
amazon_df = add_similarity_scores(amazon_df, sentences_complaint, model, "complaint_similarity")

# %%
print_top_similar_reviews(amazon_df, score_column="complaint_similarity", text_column='reviewText', top_n=20)
# Out:
# --- Review 1 ---
# Similarity Score: 0.6818
# reviewText:
# Product damaged and unusable.
#
# --- Review 2 ---
# Similarity Score: 0.6750
# reviewText:
# Beware of this product.  I opened it out of the package and I'm not sure if they treated the material for something or what but I immediately had an asthma attack and my eyes welled up and I couldn't breath I had to take multiple medications to calm my reaction down.  When my husband got home I had him check it out and he had the same problem.  We bought this for my son's birthday so we didn't open it until after the 30 day return policy was up so now I'm stuck with this thing that will most likely end up in the trash.  Do not buy this for small children especially if they have allergies or asthma.  Very strong chemical smell.  And there is no warning for this on the box.  Very disappointed especially after getting it out and my children seeing it, then having to throw it outside.
#
# --- Review 3 ---
# Similarity Score: 0.6651
# reviewText:
# I contacted the company directly to report a product that almost caused a fire and burned me, and they didn't care. They wouldn't send me a label to ship it back directly and had no interest in resolving a major product defect and potential fire hazard.
#
# --- Review 4 ---
# Similarity Score: 0.6623
# reviewText:
# I bought this product last year for a Halloween party for kids aging from 7-11.  The kids did have fun with it, however, two kids at the party had a reaction to the bubbles.  One girls face was itching and turning red in spots where the bubble hit her face and more alarming was that another boy had what looked like a chemical burn (almost blistering) on his cheek that burned.  I washed his face immediately.  I did not take him to the dr. because it wasn't getting larger and seemed to be getting better in a few days I believe it was.  But there was no warning of this.  I left a message on the companys answering machine and they called me the first thing in the morning that they opened.  They said they never heard anything like this because it is used worldwide.  I also sent them a picture of the boys cheek that was affected.  They were very good about this and had me return the bottle and paid the purchase price and the shipping for returning it.  I was hoping by now they would have put something up of some warning, maybe because I didn't go to the dr. that is why.  I showed a few nurses at church his face, and they agreed that it looked like a chemical burn.  I just want anyone out there to be careful of this product if they choose to use it.  The kids did love to play with it.  Also one of my mistakes when they played with it, is to make sure you have florescent black lights not just a black lightbulb...at least I had one flourescent bulb.  Great product if there is no side effects.
#
# --- Review 5 ---
# Similarity Score: 0.6567
# reviewText:
# Product was severely damaged.
#
# --- Review 6 ---
# Similarity Score: 0.6499
# reviewText:
# Product was intact and undamaged.
#
# --- Review 7 ---
# Similarity Score: 0.6499
# reviewText:
# DO NOT PURCHASE!!! DANGEROUS AND FAULTY MANUFACTURING PRACTICES MAKE THIS PRODUCT UNSAFE AND HARMFUL, POTENTIALLY DANGEROUS LEADING TO DEATH! I HAVE CONTACTED THE POISON CONTROL CENTER AFTER MY DAUGHTER BECAME VIOLENTLY ILL AND DISCOVERED THAT THIS TOY BEGAN LEAKING CORROSIVE BATTERY ACID! THIS TOY DESIGNED TO BE INSERTED INSIDE YOUR MOUTH IS FAULTY BY POOR DESIGN/ CARELESS MANUFACTURING PRACTICES/CHEAP MATERIALS!! THE POISON CONTROL CENTER IS CALLING ME BACK IN AN HOUR TO SEE IF SHE HAS SUFFERED FROM ANY BURNS OR LESIONS INSIDE OF HER MOUTH, GUMS, OR TONGUE. WE CANNOT GET TO A HOSPITAL BECAUSE OF SERIOUS WEATHER CONDITIONS WHICH HAS DROPPED UPWARDS OF 2-10 INCHES OF RAIN AN HOUR CAUSING MASSIVE FLOODING IN ST TAMMANY PARISH AND SURROUNDING AREAS INCLUDING OTHER STATES!!! BEWARE OF THIS PRODUCT!! IF YOU HAVE THIS PRODUCT DISPOSE OF IT IMMEDIATELY! IF YOUVE SUFFERED THE SAME CATASTROPHIC FAILURE RESULTING IN  POISONING CONTACT THE CENTER FOR POISON CONTROL AT 1-800-222-1222 THEY ARE OPEN 24hrs A DAY 7 DAYS A WEEK. I CANT BELIEVE AMAZON ALLOWS THIS PRODUCT TO BE SOLD. AFTER THIS HAPPENED TO MY DAUGHTER I READ ALL OF THE REVIEWS AND SAW THAT THIS IS NOT AN ISOLATED OCCURRENCE. DOES SOMEONE HAVE TO DIE BEFORE THEY PULL THIS "PAY TO BE POISONED" PRODUCT MANUFACTURED BY "A CHINA BASED" COMPANY?!?!
#
# --- Review 8 ---
# Similarity Score: 0.6412
# reviewText:
# We have 9 month old twin girls who liked this mirror. Seemed like a safe toy but this morning I heard one of them coughing and when I investigated I found the stitching had come undone along the side, exposing wads of the extremely fine fibrous padding material used to line the side. My daughter had a large piece of this in her mouth, which had blocked her airway and she had started choking. Only by good fortune had I heard her coughing and was able to get the material out of her mouth, which revealed a matted string had extended into her throat, causing the choking response.
#
# In my view this could have been a fatal incident. I believe this happened because of poor manufacturing standards. The padding material should have been encased in a protective sleeve, and the stitching on the hem of the mirror should have been of a much more robust nature. It's important to note that the toy had not been abused, and I would describe the usage as pretty low. Certainly far below the point the product would start to disintegrate.
#
# This is clearly an extremely dangerous product, which should be recalled immediately. The build quality is utterly sub standard and it's only a matter of time before someone else's child comes to harm as a result of the shoddy design and construction.
#
# --- Review 9 ---
# Similarity Score: 0.6376
# reviewText:
# I ordered this product as a birthday gift for my 5-year-old nephew. Needless to say, when he received it on his birthday he was so EXCITED. His dad put the slide together but by the morning after it had deflated - it had a small puncture in it that hadn't been noticed when it was assembled. As the slide was now totally waterlogged it was a little while until it could be returned - I doubt it would have been appreciated if it was returned as a dripping, soggy mess.
#
# When Amazon was contacted for a replacement we received the total run around and the final response was "too bad, so sad" and no replacement or refund was given. The fact that products can sometimes get damaged in transit is understandable but the the fact that no-one would assist in a replacement or refund, is totally beyond me.
#
# The service we received regarding this product was, quite simply, dreadful!
#
# I've been an amazon customer for years and never had an issue - but this time, the product and service was extremely poor.
#
# --- Review 10 ---
# Similarity Score: 0.6361
# reviewText:
# I rarely read (let alone write) posts such a the one I am writing here but wanted to share with you my experience with this particular toy. My 11 year old son recently played with this toy, creating a somewhat unimpressive pair of "fashion glasses" following the directions included in the project book that came in the package. While in addition to the standard
# "this plastic bag is not a toy" warning, there was also a standard "may cause skin irritation" type of warning. After declaring the toy "junk" we re-packaged it and returned it to the store. Unfortunately, not before he tried on his "fashion glasses".  Less than 24 hours later his entire face swelled with what I can only describe as chemical burns around his eyes. I re-purchased the toy in order to determine exactly what was in it. There is no indication on any of the inside packaging or box as to what the product is made of. There is however, a customer service number provided for "allergy related questions".  Unfortunately when I called, the rep simply told me there was "nothing noted in the binder". When I asked for a product specification sheet listing the ingredients I was told that no such information was available.
# Don't buy this toy. Just don't. Not only is it "junk", it's dangerous.
#
# --- Review 11 ---
# Similarity Score: 0.6303
# reviewText:
# Product was as described and undamaged
#
# --- Review 12 ---
# Similarity Score: 0.6302
# reviewText:
# My son was just hospitalized by this I'm very upset and I will be doing everything I can to sue and have this removed from shelf everywhere this is no joke and is very harmful and deadly please be more careful using this product.
#
# --- Review 13 ---
# Similarity Score: 0.6301
# reviewText:
# I ignored the several reviews that also stated they received theirs damaged, thought it was priced ok for a wood product. My box was thin but not damaged the product itself was damaged in several areas see photos, the aroma from the game is awful it filled a 3k foot house in minutes it's that strong. As others have said when dropping chips it's very LOUD. Dropping or removing the chips requires you to remove and lift up on the bottom wood bar and it sticks so not easy but not all that hard but for younger children it would be a bigger challenge. I have attempted to reach customer service left voicemail after voicemail but still no response as to what they want to do with this damaged product. Till you start seeing great positive reviews that reflect the negatives above I would stay far away from this product and possible company.
# *Update-I received a phone call from Kevin at Yardgames he addressed my concerns regarding the damaged item, packaging and the smell that radiates from this product, they have a newer version that they are now sending out, they are addressing the packaging and will address the coating of the product to prevent this smell in upcoming products. I feel more confident knowing this.
# *Update #3-received my 2nd one today and it was honestly packaged even better, but still damaged same spots. Customer service Kevin has been awesome during this process.
# *Update I received my 3rd one and this one came in perfect, the packing was greatly improved and this is a HUGE Hit in my training and Team Building exercises within our company. I'm sure this company will begin receiving additional orders based on how fun this is to play. The Customer Service is and has been extremely helpful during this process and I am looking forward to purchasing additional games to add to my collection.
#
# --- Review 14 ---
# Similarity Score: 0.6294
# reviewText:
# this maybe a very nice item presumably if newly made and not hazardous to ones health . the one i received was perhaps defective and left in a chemical bath too long after being newly made or it was used then cleaned in a chemical bath that damaged the coating on the lens . the box was heavily taped, creased and seemingly used before or damaged in transit . most notably upon opening the box, this particular item gave off a very strong plastic toxic chemical smell, that had some effects to sinuses . it does seem hazardous to be around . the plastic film was splotchy in some places over the large lens .  the items splotches makes it very hard to use . non amazon sellers are sometimes apparently dangerous to use . i am hoping to get money back and to see if others have experienced this . one does experience similar chemical residues in many items sent in the mail . this one though seemed a bit stronger and more pronounced than most i have been mailed . this was most unexpected . however curiously though, sometimes lens manufacturing and maintenance on bigger scale lenses can be very hazardous to environments and use very toxic chemicals
#
# --- Review 15 ---
# Similarity Score: 0.6291
# reviewText:
# This product has a twist motion for on and off. My 10 yr. old son was trying to turn it off and the toy popped open and what looked like rusty water sprayed out of this toy and he now has 2nd degree burns on his face, in his mouth and on his neck. Burn specialists at the ER said the battery was still intact so it is hard to determine what caused the burns. When contacting the company a supervisor did return my phone call, but did not seem interested in my situation. They stated that no complaints such as these have been reported. I insisted that they should take every complaint seriously in order to prevent any other child from being injured. Now just hoping my son's face heals.
#
# --- Review 16 ---
# Similarity Score: 0.6291
# reviewText:
# This product has a twist motion for on and off. My 10 yr. old son was trying to turn it off and the toy popped open and what looked like rusty water sprayed out of this toy and he now has 2nd degree burns on his face, in his mouth and on his neck. Burn specialists at the ER said the battery was still intact so it is hard to determine what caused the burns. When contacting the company a supervisor did return my phone call, but did not seem interested in my situation. They stated that no complaints such as these have been reported. I insisted that they should take every complaint seriously in order to prevent any other child from being injured. Now just hoping my son's face heals.
#
# --- Review 17 ---
# Similarity Score: 0.6276
# reviewText:
# The package was broken  and pieces were everywhere in the envelope and on the back it actually said could be poison and could effect health.  It was horrible. My husband threw it away instead of returning the product
#
# --- Review 18 ---
# Similarity Score: 0.6276
# reviewText:
# Product showed up damaged.
#
# --- Review 19 ---
# Similarity Score: 0.6251
# reviewText:
# The product was dirty and some of it was damaged.
#
# --- Review 20 ---
# Similarity Score: 0.6248
# reviewText:
# Arrived damaged in several spots.  Unusable.

# %% [markdown]
# ## Shipping Related SImilarity Scores:

# %%
sentence_shipping = [
    "The package arrived late and the box was completely crushed.",
    "Item was missing from the box when it finally showed up.",
    "Took over two weeks to deliver, and it was the wrong item.",
    "Product arrived broken with pieces rattling in the box.",
    "Shipping took forever and tracking info was never updated.",
    "It never arrived. I had to contact customer service twice to get a refund.",
    "Arrived open and missing the accessories. Very disappointing.",
    "The outer box was soaked and falling apart. Product was unusable.",
    "Delivery was delayed multiple times. Not acceptable for a paid service.",
    "Item was tossed at the door. Packaging was torn and dented.",
    "Poorly packaged.",
    "Product was severely damaged"
]

# %%
amazon_df = add_similarity_scores(amazon_df, sentence_shipping, model, "shipping_similarity")

# %%
print_top_similar_reviews(amazon_df, score_column="shipping_similarity", text_column='reviewText', top_n=20)
# Out:
# --- Review 1 ---
# Similarity Score: 0.8184
# reviewText:
# package came damaged, the box was squished and broken.
#
# --- Review 2 ---
# Similarity Score: 0.8180
# reviewText:
# It was delivered all out of the box, open and broken.
#
# --- Review 3 ---
# Similarity Score: 0.8168
# reviewText:
# Box was badly damaged during shipping.
#
# --- Review 4 ---
# Similarity Score: 0.8126
# reviewText:
# The package was received damaged.
#
# --- Review 5 ---
# Similarity Score: 0.8115
# reviewText:
# It was just as expected though the box was damaged on arrival, the product was intact.
#
# --- Review 6 ---
# Similarity Score: 0.8106
# reviewText:
# Package was damaged upon arrival. Very disappointing.
#
# --- Review 7 ---
# Similarity Score: 0.8087
# reviewText:
# Package came slightly damaged and some of the box was scratched and dented.
#
# --- Review 8 ---
# Similarity Score: 0.8068
# reviewText:
# The delivery was super late, and the product came damaged.
#
# --- Review 9 ---
# Similarity Score: 0.8068
# reviewText:
# poor packaging, arrived broken.
#
# --- Review 10 ---
# Similarity Score: 0.8062
# reviewText:
# Delivery took a long time and item was broken.
#
# --- Review 11 ---
# Similarity Score: 0.8060
# reviewText:
# Product package arrived damaged.
#
# --- Review 12 ---
# Similarity Score: 0.8058
# reviewText:
# Item arrived on time but was broken in the box.
#
# --- Review 13 ---
# Similarity Score: 0.8050
# reviewText:
# Product packaging arrived damaged.
#
# --- Review 14 ---
# Similarity Score: 0.8049
# reviewText:
# Arrived quickly. Box was a bit crushed but the product itself was undamaged.
#
# --- Review 15 ---
# Similarity Score: 0.8048
# reviewText:
# Box arrived damaged. Ordered over holidays, and there wasn't enough time to process an exchange.
#
# --- Review 16 ---
# Similarity Score: 0.8027
# reviewText:
# The package was delivered damaged.
#
# --- Review 17 ---
# Similarity Score: 0.8024
# reviewText:
# The package was damaged at arrival.
#
# --- Review 18 ---
# Similarity Score: 0.8018
# reviewText:
# Product was delivered on time. Package was damaged
#
# --- Review 19 ---
# Similarity Score: 0.8018
# reviewText:
# Box was damaged upon arrival. Product seems unharmed.
#
# --- Review 20 ---
# Similarity Score: 0.8016
# reviewText:
# The package arrived very early and the box was undamaged. Overall a good buy.

# %% [markdown]
# ### Improving Similarity Score Precision with Sentiment Filtering
#
# While computing similarity scores between review embeddings and a complaint-related reference vector helped identify potential safety issues, we observed false positives: several reviews with high similarity scores were actually positive in sentiment. These reviews often mentioned terms like "product", "damage" or "issue" in a non-negative context.
#
# To address this, we incorporated a sentiment classification layer. For reviews classified as positive, we set their similarity score to zero, ensuring that reviews with high semantic similarity but positive tone are not mistakenly flagged. This hybrid approach improves our model’s precision by filtering out irrelevant matches that share complaint-related vocabulary but not complaint-related intent.

# %%
# Save the amazon_df with new columns:
amazon_df.drop("complaint_similarity5", axis=1, inplace=True)
amazon_df.to_parquet("amazon_reviews_with_similarity_scores.parquet", index=True)

# %%
amazon_df = pd.read_parquet("amazon_reviews_with_similarity_scores.parquet")

# %%
amazon_df.shape
# Out:
# (8201231, 19)

# %%
amazon_df.columns
# Out:
# Index(['overall', 'vote', 'verified', 'reviewTime', 'reviewerID', 'asin',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'image',
#        'style', 'review_len_words', 'review_len_chars', 'reviewText_clean',
#        'embedding', 'complaint_similarity', 'shipping_similarity',
#        'sentiment'],
#       dtype='object')

# %% [markdown]
# ## Drop Null Values and Some Columns:

# %%
amazon_df = amazon_df.dropna(subset=['summary','reviewText', 'reviewerName'])

# %%
amazon_df = amazon_df.drop(columns=['image', 'vote', 'style', 'reviewTime'])

# %%
amazon_df.shape
# Out:
# (8191295, 15)

# %%
duplicates = amazon_df.duplicated(subset=['reviewerID', 'asin', 'unixReviewTime', 'overall'], keep=False)
print(f"Number of duplicate reviews: {duplicates.sum()}")
# Out:
# Number of duplicate reviews: 391965

# %% [markdown]
# ## Calculating Similarity Scores Based on Sentiments

# %%
import torch
from torch.nn.functional import softmax
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from tqdm import tqdm
import pandas as pd

# Load model and tokenizer once
model_name = "distilbert-base-uncased-finetuned-sst-2-english"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model_sent = AutoModelForSequenceClassification.from_pretrained(model_name)

def batched_sentiment_scores(texts, batch_size=64, score_type="positive"):
    """
    Returns sentiment scores (probability of POSITIVE or NEGATIVE) for input texts.
    """
    sentiment_scores = []
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model_sent.to(device)

    for i in tqdm(range(0, len(texts), batch_size), desc="Sentiment Scoring"):
        batch_texts = texts[i:i+batch_size]

        # Tokenize and move to device
        inputs = tokenizer(batch_texts, return_tensors='pt', truncation=True, padding=True)
        inputs = {k: v.to(device) for k, v in inputs.items()}

        # Run inference
        with torch.no_grad():
            logits = model_sent(**inputs).logits
            probs = softmax(logits, dim=1).cpu().numpy()

        # Score index: 0 = NEGATIVE, 1 = POSITIVE
        idx = 1 if score_type.lower() == "positive" else 0
        sentiment_scores.extend(probs[:, idx])

    return sentiment_scores
# Out:
# C:\Users\Betul\anaconda3\envs\pytorch_env\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
amazon_df['positive_sentiment_score'] = batched_sentiment_scores(
    amazon_df['summary'].fillna("").tolist(), 
    batch_size=64, 
    score_type="positive"
)
# Out:
# Sentiment Scoring: 100%|███████████████████████████████████████████████████████| 127989/127989 [28:07<00:00, 75.83it/s]

# %%
positive_sentiment_score = amazon_df['positive_sentiment_score']

# %%
def print_top_similar_reviews_sentiment(df, score_column, text_column='reviewText', top_n=20):
    # Sort and get top reviews
    top_reviews = df.sort_values(by=score_column, ascending=False).head(top_n)

    # Print them nicely
    for i, (_, row) in enumerate(top_reviews.iterrows(), 1):
        print(f"--- Review {i} ---")
        print(f"Similarity Score: {row[score_column]:.4f}")
        print(f"Sentiment: {row['positive_sentiment_score']}")
        print(f"{text_column}:\n{row[text_column]}\n")

# %%
print_top_similar_reviews_sentiment(amazon_df, score_column="complaint_similarity", text_column='reviewText', top_n=20)
# Out:
# --- Review 1 ---
# Similarity Score: 0.6818
# Sentiment: 0.000347054039593786
# reviewText:
# Product damaged and unusable.
#
# --- Review 2 ---
# Similarity Score: 0.6750
# Sentiment: 0.027122223749756813
# reviewText:
# Beware of this product.  I opened it out of the package and I'm not sure if they treated the material for something or what but I immediately had an asthma attack and my eyes welled up and I couldn't breath I had to take multiple medications to calm my reaction down.  When my husband got home I had him check it out and he had the same problem.  We bought this for my son's birthday so we didn't open it until after the 30 day return policy was up so now I'm stuck with this thing that will most likely end up in the trash.  Do not buy this for small children especially if they have allergies or asthma.  Very strong chemical smell.  And there is no warning for this on the box.  Very disappointed especially after getting it out and my children seeing it, then having to throw it outside.
#
# --- Review 3 ---
# Similarity Score: 0.6651
# Sentiment: 0.016852473840117455
# reviewText:
# I contacted the company directly to report a product that almost caused a fire and burned me, and they didn't care. They wouldn't send me a label to ship it back directly and had no interest in resolving a major product defect and potential fire hazard.
#
# --- Review 4 ---
# Similarity Score: 0.6623
# Sentiment: 0.04538879916071892
# reviewText:
# I bought this product last year for a Halloween party for kids aging from 7-11.  The kids did have fun with it, however, two kids at the party had a reaction to the bubbles.  One girls face was itching and turning red in spots where the bubble hit her face and more alarming was that another boy had what looked like a chemical burn (almost blistering) on his cheek that burned.  I washed his face immediately.  I did not take him to the dr. because it wasn't getting larger and seemed to be getting better in a few days I believe it was.  But there was no warning of this.  I left a message on the companys answering machine and they called me the first thing in the morning that they opened.  They said they never heard anything like this because it is used worldwide.  I also sent them a picture of the boys cheek that was affected.  They were very good about this and had me return the bottle and paid the purchase price and the shipping for returning it.  I was hoping by now they would have put something up of some warning, maybe because I didn't go to the dr. that is why.  I showed a few nurses at church his face, and they agreed that it looked like a chemical burn.  I just want anyone out there to be careful of this product if they choose to use it.  The kids did love to play with it.  Also one of my mistakes when they played with it, is to make sure you have florescent black lights not just a black lightbulb...at least I had one flourescent bulb.  Great product if there is no side effects.
#
# --- Review 5 ---
# Similarity Score: 0.6567
# Sentiment: 0.9622771739959717
# reviewText:
# Product was severely damaged.
#
# --- Review 6 ---
# Similarity Score: 0.6499
# Sentiment: 0.9997640252113342
# reviewText:
# Product was intact and undamaged.
#
# --- Review 7 ---
# Similarity Score: 0.6499
# Sentiment: 0.0064238193444907665
# reviewText:
# DO NOT PURCHASE!!! DANGEROUS AND FAULTY MANUFACTURING PRACTICES MAKE THIS PRODUCT UNSAFE AND HARMFUL, POTENTIALLY DANGEROUS LEADING TO DEATH! I HAVE CONTACTED THE POISON CONTROL CENTER AFTER MY DAUGHTER BECAME VIOLENTLY ILL AND DISCOVERED THAT THIS TOY BEGAN LEAKING CORROSIVE BATTERY ACID! THIS TOY DESIGNED TO BE INSERTED INSIDE YOUR MOUTH IS FAULTY BY POOR DESIGN/ CARELESS MANUFACTURING PRACTICES/CHEAP MATERIALS!! THE POISON CONTROL CENTER IS CALLING ME BACK IN AN HOUR TO SEE IF SHE HAS SUFFERED FROM ANY BURNS OR LESIONS INSIDE OF HER MOUTH, GUMS, OR TONGUE. WE CANNOT GET TO A HOSPITAL BECAUSE OF SERIOUS WEATHER CONDITIONS WHICH HAS DROPPED UPWARDS OF 2-10 INCHES OF RAIN AN HOUR CAUSING MASSIVE FLOODING IN ST TAMMANY PARISH AND SURROUNDING AREAS INCLUDING OTHER STATES!!! BEWARE OF THIS PRODUCT!! IF YOU HAVE THIS PRODUCT DISPOSE OF IT IMMEDIATELY! IF YOUVE SUFFERED THE SAME CATASTROPHIC FAILURE RESULTING IN  POISONING CONTACT THE CENTER FOR POISON CONTROL AT 1-800-222-1222 THEY ARE OPEN 24hrs A DAY 7 DAYS A WEEK. I CANT BELIEVE AMAZON ALLOWS THIS PRODUCT TO BE SOLD. AFTER THIS HAPPENED TO MY DAUGHTER I READ ALL OF THE REVIEWS AND SAW THAT THIS IS NOT AN ISOLATED OCCURRENCE. DOES SOMEONE HAVE TO DIE BEFORE THEY PULL THIS "PAY TO BE POISONED" PRODUCT MANUFACTURED BY "A CHINA BASED" COMPANY?!?!
#
# --- Review 8 ---
# Similarity Score: 0.6412
# Sentiment: 0.000786930846516043
# reviewText:
# We have 9 month old twin girls who liked this mirror. Seemed like a safe toy but this morning I heard one of them coughing and when I investigated I found the stitching had come undone along the side, exposing wads of the extremely fine fibrous padding material used to line the side. My daughter had a large piece of this in her mouth, which had blocked her airway and she had started choking. Only by good fortune had I heard her coughing and was able to get the material out of her mouth, which revealed a matted string had extended into her throat, causing the choking response.
#
# In my view this could have been a fatal incident. I believe this happened because of poor manufacturing standards. The padding material should have been encased in a protective sleeve, and the stitching on the hem of the mirror should have been of a much more robust nature. It's important to note that the toy had not been abused, and I would describe the usage as pretty low. Certainly far below the point the product would start to disintegrate.
#
# This is clearly an extremely dangerous product, which should be recalled immediately. The build quality is utterly sub standard and it's only a matter of time before someone else's child comes to harm as a result of the shoddy design and construction.
#
# --- Review 9 ---
# Similarity Score: 0.6376
# Sentiment: 0.00020881916861981153
# reviewText:
# I ordered this product as a birthday gift for my 5-year-old nephew. Needless to say, when he received it on his birthday he was so EXCITED. His dad put the slide together but by the morning after it had deflated - it had a small puncture in it that hadn't been noticed when it was assembled. As the slide was now totally waterlogged it was a little while until it could be returned - I doubt it would have been appreciated if it was returned as a dripping, soggy mess.
#
# When Amazon was contacted for a replacement we received the total run around and the final response was "too bad, so sad" and no replacement or refund was given. The fact that products can sometimes get damaged in transit is understandable but the the fact that no-one would assist in a replacement or refund, is totally beyond me.
#
# The service we received regarding this product was, quite simply, dreadful!
#
# I've been an amazon customer for years and never had an issue - but this time, the product and service was extremely poor.
#
# --- Review 10 ---
# Similarity Score: 0.6361
# Sentiment: 0.0026633599773049355
# reviewText:
# I rarely read (let alone write) posts such a the one I am writing here but wanted to share with you my experience with this particular toy. My 11 year old son recently played with this toy, creating a somewhat unimpressive pair of "fashion glasses" following the directions included in the project book that came in the package. While in addition to the standard
# "this plastic bag is not a toy" warning, there was also a standard "may cause skin irritation" type of warning. After declaring the toy "junk" we re-packaged it and returned it to the store. Unfortunately, not before he tried on his "fashion glasses".  Less than 24 hours later his entire face swelled with what I can only describe as chemical burns around his eyes. I re-purchased the toy in order to determine exactly what was in it. There is no indication on any of the inside packaging or box as to what the product is made of. There is however, a customer service number provided for "allergy related questions".  Unfortunately when I called, the rep simply told me there was "nothing noted in the binder". When I asked for a product specification sheet listing the ingredients I was told that no such information was available.
# Don't buy this toy. Just don't. Not only is it "junk", it's dangerous.
#
# --- Review 11 ---
# Similarity Score: 0.6303
# Sentiment: 0.9990085959434509
# reviewText:
# Product was as described and undamaged
#
# --- Review 12 ---
# Similarity Score: 0.6302
# Sentiment: 0.003408738411962986
# reviewText:
# My son was just hospitalized by this I'm very upset and I will be doing everything I can to sue and have this removed from shelf everywhere this is no joke and is very harmful and deadly please be more careful using this product.
#
# --- Review 13 ---
# Similarity Score: 0.6301
# Sentiment: 0.03858739510178566
# reviewText:
# I ignored the several reviews that also stated they received theirs damaged, thought it was priced ok for a wood product. My box was thin but not damaged the product itself was damaged in several areas see photos, the aroma from the game is awful it filled a 3k foot house in minutes it's that strong. As others have said when dropping chips it's very LOUD. Dropping or removing the chips requires you to remove and lift up on the bottom wood bar and it sticks so not easy but not all that hard but for younger children it would be a bigger challenge. I have attempted to reach customer service left voicemail after voicemail but still no response as to what they want to do with this damaged product. Till you start seeing great positive reviews that reflect the negatives above I would stay far away from this product and possible company.
# *Update-I received a phone call from Kevin at Yardgames he addressed my concerns regarding the damaged item, packaging and the smell that radiates from this product, they have a newer version that they are now sending out, they are addressing the packaging and will address the coating of the product to prevent this smell in upcoming products. I feel more confident knowing this.
# *Update #3-received my 2nd one today and it was honestly packaged even better, but still damaged same spots. Customer service Kevin has been awesome during this process.
# *Update I received my 3rd one and this one came in perfect, the packing was greatly improved and this is a HUGE Hit in my training and Team Building exercises within our company. I'm sure this company will begin receiving additional orders based on how fun this is to play. The Customer Service is and has been extremely helpful during this process and I am looking forward to purchasing additional games to add to my collection.
#
# --- Review 14 ---
# Similarity Score: 0.6294
# Sentiment: 0.005156520288437605
# reviewText:
# this maybe a very nice item presumably if newly made and not hazardous to ones health . the one i received was perhaps defective and left in a chemical bath too long after being newly made or it was used then cleaned in a chemical bath that damaged the coating on the lens . the box was heavily taped, creased and seemingly used before or damaged in transit . most notably upon opening the box, this particular item gave off a very strong plastic toxic chemical smell, that had some effects to sinuses . it does seem hazardous to be around . the plastic film was splotchy in some places over the large lens .  the items splotches makes it very hard to use . non amazon sellers are sometimes apparently dangerous to use . i am hoping to get money back and to see if others have experienced this . one does experience similar chemical residues in many items sent in the mail . this one though seemed a bit stronger and more pronounced than most i have been mailed . this was most unexpected . however curiously though, sometimes lens manufacturing and maintenance on bigger scale lenses can be very hazardous to environments and use very toxic chemicals
#
# --- Review 15 ---
# Similarity Score: 0.6291
# Sentiment: 0.0026633611414581537
# reviewText:
# This product has a twist motion for on and off. My 10 yr. old son was trying to turn it off and the toy popped open and what looked like rusty water sprayed out of this toy and he now has 2nd degree burns on his face, in his mouth and on his neck. Burn specialists at the ER said the battery was still intact so it is hard to determine what caused the burns. When contacting the company a supervisor did return my phone call, but did not seem interested in my situation. They stated that no complaints such as these have been reported. I insisted that they should take every complaint seriously in order to prevent any other child from being injured. Now just hoping my son's face heals.
#
# --- Review 16 ---
# Similarity Score: 0.6291
# Sentiment: 0.0026633611414581537
# reviewText:
# This product has a twist motion for on and off. My 10 yr. old son was trying to turn it off and the toy popped open and what looked like rusty water sprayed out of this toy and he now has 2nd degree burns on his face, in his mouth and on his neck. Burn specialists at the ER said the battery was still intact so it is hard to determine what caused the burns. When contacting the company a supervisor did return my phone call, but did not seem interested in my situation. They stated that no complaints such as these have been reported. I insisted that they should take every complaint seriously in order to prevent any other child from being injured. Now just hoping my son's face heals.
#
# --- Review 17 ---
# Similarity Score: 0.6276
# Sentiment: 0.0005320993950590491
# reviewText:
# The package was broken  and pieces were everywhere in the envelope and on the back it actually said could be poison and could effect health.  It was horrible. My husband threw it away instead of returning the product
#
# --- Review 18 ---
# Similarity Score: 0.6276
# Sentiment: 0.03375214710831642
# reviewText:
# Product showed up damaged.
#
# --- Review 19 ---
# Similarity Score: 0.6251
# Sentiment: 0.033752039074897766
# reviewText:
# The product was dirty and some of it was damaged.
#
# --- Review 20 ---
# Similarity Score: 0.6248
# Sentiment: 0.03375214710831642
# reviewText:
# Arrived damaged in several spots.  Unusable.

# %%
amazon_df.to_parquet("amazon_reviews_with_sim_sent_scores.parquet", index=True)

# %%
amazon_df = pd.read_parquet("amazon_reviews_with_sim_sent_scores.parquet")

# %%
amazon_df.dropna(subset=['embedding'], inplace=True)

# %% [markdown]
# ## Aggregate Features

# %% [markdown]
# ### Mean Sentiment Score:

# %%
mean_scores_by_asin = amazon_df.groupby('asin').agg({
    'positive_sentiment_score': 'mean',
    'complaint_similarity': 'mean',
    'shipping_similarity': 'mean'
}).reset_index()

mean_scores_by_asin.rename(columns={
    'positive_sentiment_score': 'mean_sentiment_score',
    'complaint_similarity': 'mean_complaint_similarity',
    'shipping_similarity': 'mean_shipping_similarity'
}, inplace=True)

# %%
max_complaint_idx = amazon_df.groupby('asin')['complaint_similarity'].idxmax()
max_rows = amazon_df.loc[max_complaint_idx, ['asin', 'complaint_similarity', 'shipping_similarity', 'positive_sentiment_score']]
max_rows = max_rows.rename(columns={
    'complaint_similarity': 'max_complaint_similarity',
    'shipping_similarity': 'shipping_similarity_at_max_complaint',
    'positive_sentiment_score': 'sentiment_score_at_max_complaint'
})

# %%
mean_scores_by_asin.head()
# Out:
#          asin  mean_sentiment_score  mean_complaint_similarity  \
# 0  0000191639              0.871852                   0.043511
# 1  0004950763              0.999009                   0.022326
# 2  0004983289              0.999608                   0.010901
# 3  0005069491              0.030873                   0.074038
# 4  0006466222              0.999009                   0.035320
#
#    mean_shipping_similarity
# 0                  0.176900
# 1                  0.086034
# 2                  0.104040
# 3                  0.085383
# 4                  0.129227

# %%
max_rows.head()
# Out:
#                asin  max_complaint_similarity  \
# 5742413  0000191639                  0.043511
# 6515097  0004950763                  0.022326
# 5742417  0004983289                  0.045305
# 6697985  0005069491                  0.074038
# 5742419  0006466222                  0.035320
#
#          shipping_similarity_at_max_complaint  \
# 5742413                              0.176900
# 6515097                              0.086034
# 5742417                              0.229722
# 6697985                              0.085383
# 5742419                              0.129227
#
#          sentiment_score_at_max_complaint
# 5742413                          0.871852
# 6515097                          0.999009
# 5742417                          0.999874
# 6697985                          0.030873
# 5742419                          0.999009

# %% [markdown]
# ## Weighted Embedding and Mean Embedding of ReviewText

# %%
def combined_embedding(group, alpha=0.5):
    embeddings = np.vstack(group['embedding'])
    sentiment_scores = group['positive_sentiment_score'].values

    # Mean embedding (standard average)
    mean_emb = embeddings.mean(axis=0)

    # Weighted embedding (more weight to negative reviews)
    weights = 1 - sentiment_scores
    if weights.sum() == 0:
        weights = np.ones_like(weights)
    weights = weights / weights.sum()
    weighted_emb = np.average(embeddings, axis=0, weights=weights)

    # Final combined embedding
    return alpha * weighted_emb + (1 - alpha) * mean_emb

# %%
# Compute final embeddings per ASIN
review_embeddings = review_embeddings = amazon_df.groupby('asin')[['embedding', 'positive_sentiment_score']].apply(combined_embedding)

# %%
embedding_df = pd.DataFrame(review_embeddings.tolist(), index=review_embeddings.index)
embedding_df.columns = [f'embedding_{i}' for i in range(embedding_df.shape[1])]
embedding_df = embedding_df.reset_index()

# %%
embedding_df.head()
# Out:
#          asin  embedding_0  embedding_1  embedding_2  embedding_3  \
# 0  0000191639     0.027758     0.065257     0.017953    -0.051408
# 1  0004950763    -0.094509     0.001439     0.047510    -0.052813
# 2  0004983289     0.003233     0.037895    -0.020209    -0.065908
# 3  0005069491    -0.019407    -0.085453     0.039475    -0.008537
# 4  0006466222    -0.043714     0.038217    -0.052901     0.010238
#
#    embedding_4  embedding_5  embedding_6  embedding_7  embedding_8  ...  \
# 0    -0.115517     0.043882    -0.052921    -0.040914    -0.055210  ...
# 1    -0.019436    -0.030759     0.070818    -0.023990     0.047919  ...
# 2    -0.076476     0.015781     0.030195    -0.062512     0.004691  ...
# 3    -0.043666     0.025446     0.028984    -0.028728     0.055470  ...
# 4    -0.103368    -0.003938     0.033670     0.066004     0.091853  ...
#
#    embedding_374  embedding_375  embedding_376  embedding_377  embedding_378  \
# 0       0.081221       0.000930       0.020542      -0.000513      -0.017386
# 1       0.029028       0.017909      -0.015086      -0.018589       0.001332
# 2       0.094576       0.031822      -0.011569       0.012821       0.026619
# 3       0.029462       0.064632      -0.056036       0.085632      -0.007459
# 4       0.067709      -0.049012      -0.038670      -0.042237      -0.067665
#
#    embedding_379  embedding_380  embedding_381  embedding_382  embedding_383
# 0       0.039457      -0.001327       0.092034       0.026612       0.110444
# 1       0.042599       0.161014      -0.016039      -0.000539       0.075859
# 2       0.047444       0.065055       0.032397      -0.048743       0.048678
# 3       0.025162      -0.024561       0.022096       0.016897       0.061657
# 4       0.007688       0.146708       0.049473       0.004074      -0.054181
#
# [5 rows x 385 columns]

# %%
review_features_df = embedding_df.merge(mean_scores_by_asin, on='asin', how='inner')
review_features_df = review_features_df.merge(max_rows, on='asin', how='inner')

# %%
review_features_df.columns
# Out:
# Index(['asin', 'embedding_0', 'embedding_1', 'embedding_2', 'embedding_3',
#        'embedding_4', 'embedding_5', 'embedding_6', 'embedding_7',
#        'embedding_8',
#        ...
#        'embedding_380', 'embedding_381', 'embedding_382', 'embedding_383',
#        'mean_sentiment_score', 'mean_complaint_similarity',
#        'mean_shipping_similarity', 'max_complaint_similarity',
#        'shipping_similarity_at_max_complaint',
#        'sentiment_score_at_max_complaint'],
#       dtype='object', length=391)

# %%
review_features_df.shape
# Out:
# (624529, 391)

# %%
review_features_df.head()
# Out:
#          asin  embedding_0  embedding_1  embedding_2  embedding_3  \
# 0  0000191639     0.027758     0.065257     0.017953    -0.051408
# 1  0004950763    -0.094509     0.001439     0.047510    -0.052813
# 2  0004983289     0.003233     0.037895    -0.020209    -0.065908
# 3  0005069491    -0.019407    -0.085453     0.039475    -0.008537
# 4  0006466222    -0.043714     0.038217    -0.052901     0.010238
#
#    embedding_4  embedding_5  embedding_6  embedding_7  embedding_8  ...  \
# 0    -0.115517     0.043882    -0.052921    -0.040914    -0.055210  ...
# 1    -0.019436    -0.030759     0.070818    -0.023990     0.047919  ...
# 2    -0.076476     0.015781     0.030195    -0.062512     0.004691  ...
# 3    -0.043666     0.025446     0.028984    -0.028728     0.055470  ...
# 4    -0.103368    -0.003938     0.033670     0.066004     0.091853  ...
#
#    embedding_380  embedding_381  embedding_382  embedding_383  \
# 0      -0.001327       0.092034       0.026612       0.110444
# 1       0.161014      -0.016039      -0.000539       0.075859
# 2       0.065055       0.032397      -0.048743       0.048678
# 3      -0.024561       0.022096       0.016897       0.061657
# 4       0.146708       0.049473       0.004074      -0.054181
#
#    mean_sentiment_score  mean_complaint_similarity  mean_shipping_similarity  \
# 0              0.871852                   0.043511                  0.176900
# 1              0.999009                   0.022326                  0.086034
# 2              0.999608                   0.010901                  0.104040
# 3              0.030873                   0.074038                  0.085383
# 4              0.999009                   0.035320                  0.129227
#
#    max_complaint_similarity  shipping_similarity_at_max_complaint  \
# 0                  0.043511                              0.176900
# 1                  0.022326                              0.086034
# 2                  0.045305                              0.229722
# 3                  0.074038                              0.085383
# 4                  0.035320                              0.129227
#
#    sentiment_score_at_max_complaint
# 0                          0.871852
# 1                          0.999009
# 2                          0.999874
# 3                          0.030873
# 4                          0.999009
#
# [5 rows x 391 columns]

# %%
review_features_df.to_pickle("../Data/review_features_df.pkl")
